# %% [markdown]
# ## 1. OBJECTIVE

# %% [markdown]
# Concordance analysis allows us to see a given word or bigram in context to provide more insight about the meaning.

# %% [markdown]
# ## 2. SETUP

# %%
import json
from collections import Counter

# %%
# import modules

import os
import random
import re
import string

import json
from collections import Counter

# %%
### PARAMETERS

to_strip = ',.\xa0:-()\';$"/?][!`Ą@Ś§¨’–“”…ï‘>&\\%˝˘*'

# %% [markdown]
# ## 3. FUNCTIONS

# %%
def tokenize(text, lowercase=True, strip_chars=''):
    '''turn a string into a list of whitespace separated tokens - after observing lowercase flag and stripping specified characters
    
    Args:
        text        -- a string object containing the text to be tokenized
        lowercase   -- whether the string should be lowercased before tokenization (default: True)
        strip_chars -- a string containing a series of characters which should be stripped from text before tokenization (default: empty string)
        
    
    Returns:
        list of tokens
    '''
    if lowercase:
        text = text.lower()
        
    rdict = str.maketrans('','',strip_chars)
    text = text.translate(rdict)
        
    tokens=text.split()
    
    return tokens

# %%
def make_kwic(kw, text, win=4):
    '''A basic KWIC function for a text
    
    Args:
        kw   -- string match for keyword to match for each line
        text -- a list of tokens for the text
        
    Return:
        list of lines of form [ [left context words], kw, [right context words]]
    '''
    
    hits = [(w,i) for i,w in enumerate(text) if w==kw]
    
    lines = []
    for hit in hits:
        hidx = hit[1]
        left = text[hidx-win:hidx]
        kw = hit[0]
        right = text[hidx+1 : hidx+win+1]
        
        left = ['']*len(left)-win + left if len(left)<win else left
        
        right = right + ['']*len(left)-win  if len(right)<win else right
        
        lines.append([left, kw, right])
        
    return lines

# %%
#multi-word KWIC function put together by Prof. O'Donnell
def make_kwic2(kw, text, win=4):
    '''A basic KWIC function for a text
    
    Args:
        kw   -- string match for keyword to match for each line if it contains spaces split into list of kws
        text -- a list of tokens for the text
        
    Return:
        list of lines of form [ [left context words], kw, [right context words]]
    '''
    
    
    kw_toks = kw.split()
    kw_width = len(kw_toks)
    
    hits = []
    for i,w in enumerate(text):
        match = text[i:i+kw_width]
        if match==kw_toks:
            hits.append((' '.join(kw_toks),i))
    
    
    lines = []
    for hit in hits:
        left = text[hit[1]-win:hit[1]]
        kw = ' '.join(text[hit[1]:hit[1]+kw_width])
        right = text[hit[1]+kw_width : hit[1]+win+kw_width]
        
        
        left = ['']*(win-len(left)) + left if len(left)<win else left
        right = right+['']*(win-len(right)) if len(right)<win else right

        
        lines.append([left, kw, right])
        
    return lines

# %%
def print_kwic(kwic, win=None):
    '''A basic print function for a KWIC object
    
    Args:
        kwic -- a list of KWIC lines of the form [ [left words], kw, [right words]]
        win  -- if None then use all words provided in context otherwise limit by win
        
    Prints KWIC lines with left context width/padding win*8 characters
    '''
    
    if not kwic:
        return
    
    if win is None:
        win = len(kwic[0][0])
    
    for line in kwic:
        print("{: >{}}  {}  {}".format(' '.join(line[0][-win:]), 
                                      win*8, 
                                      line[1], 
                                      ' '.join(line[2][:win])
                                     )
             )

# %%
def sort_kwic(kwic, order=None):
    ''' sort a kwic list using the passed positional arguments 
    
    Args:
        kwic   -- a list of lists [ [left tokens], kw, [right tokens]]
        order  -- a list of one or more positional arguments of form side-pos, e.g. L1, R3, L4 (default: None)
    
    Returns:
        kwic sorted for each positional argument in reverse, i.e. ['R1','L1'] sorts first by L1 and then R1
    '''
    if order is None:
        return kwic
   
    order = [order] if not type(order) is list else order
    order.reverse()
    
    for sort_term in order:
        if not re.match('[LR][1-4]', sort_term):
            pass
        
        pos1 = 0 if sort_term[0]=='L' else 2
        pos2 = int(sort_term[1])-1
        pos2 = 3-pos2 if sort_term[0]=='L' else pos2
        kwic.sort(key=lambda l : l[pos1][pos2])
    
    return kwic

# %% [markdown]
# I made some edits to the make_kwic2 function in order for me to use the findings for sentiment analysis.

# %%
def make_kwic2_as_text(kw, text, win=4):
    '''A basic KWIC function for a text
    
    Args:
        kw   -- string match for keyword to match for each line if it contains spaces split into list of kws
        text -- a list of tokens for the text
        
    Return:
        list of lines of form [ [left context words], kw, [right context words]]
    '''
    
    
    kw_toks = kw.split()
    kw_width = len(kw_toks)
    
    hits = []
    for i,w in enumerate(text):
        match = text[i:i+kw_width]
        if match==kw_toks:
            hits.append((' '.join(kw_toks),i))
    
    
    lines = []
    for hit in hits:
        left = text[hit[1]-win:hit[1]]
        kw = ' '.join(text[hit[1]:hit[1]+kw_width])
        right = text[hit[1]+kw_width : hit[1]+win+kw_width]
        
        
        left = ['']*(win-len(left)) + left if len(left)<win else left
        right = right+['']*(win-len(right)) if len(right)<win else right

        
        lines.extend([left + right])
        
    return lines

# %%
def make_kwic_as_text(kw, text, win=4):
    '''A basic KWIC function for a text
    
    Args:
        kw   -- string match for keyword to match for each line
        text -- a list of tokens for the text
        
    Return:
        list of lines of form [ [left context words], kw, [right context words]]
    '''
    
    hits = [(w,i) for i,w in enumerate(text) if w==kw]
    
    lines = []
    for hit in hits:
        hidx = hit[1]
        left = text[hidx-win:hidx]
        kw = hit[0]
        right = text[hidx+1 : hidx+win+1]
        
        left = ['']*len(left)-win + left if len(left)<win else left
        
        right = right + ['']*len(left)-win  if len(right)<win else right
        
        lines.append(left + right)
        
    return lines

# %% [markdown]
# ## 4. LOAD DATA

# %%
corpus = json.load(open('data/briefing_transcripts.json'))

# %%
apr_briefings = [item for item in corpus if item['date'].split()[0]=='Apr']
mar_briefings = [item for item in corpus if item['date'].split()[0]=='Mar']
feb_briefings = [item for item in corpus if item['date'].split()[0]=='Feb']
jan_briefings = [item for item in corpus if item['date'].split()[0]=='Jan']

# %%
# set up a list for April tokens
apr_tokens = []

# process each of the April briefings
for briefing in apr_briefings:
    
    # get the text string for the transcript of current briefing
    briefing_text = briefing['text']
    
    # get a list of tokens for this text
    tokens = tokenize(briefing_text, lowercase=True, strip_chars=to_strip)
    
    # update the list of tokens
    apr_tokens.extend(tokens)

# %%
jan_tokens = []
for briefing in jan_briefings:
    briefing_text = briefing['text']
    tokens = tokenize(briefing_text, lowercase=True, strip_chars=to_strip)
    jan_tokens.extend(tokens)

# %%
mar_tokens = []
for briefing in mar_briefings:
    briefing_text = briefing['text']
    tokens = tokenize(briefing_text, lowercase=True, strip_chars=to_strip)
    mar_tokens.extend(tokens)

# %% [markdown]
# ### He Did: April

# %%
apr_kwic_hedid = make_kwic2("he did", apr_tokens, win=6)

# %%
len(apr_kwic_hedid)
# Out:
# 40

# %%
print_kwic(sort_kwic(apr_kwic_hedid, order= ['R6']))
# Out:
#                  you that sir the president yeah  he did  say that actually russia talked about
#                         few people can do it and  he did  it well and then he became
#                       didnt know about it and if  he did  know about it he wouldve been
#                         so he didnt go crazy but  he did  say — q your ban bought
#                   happened there and i had heard  he did  because he didnt want to cause
#                    how did president trump do oh  he did  uh terribly lets see he did
#                ban bought you time the president  he did  call me xenophobic q what did
#                         i didnt speak to him but  he did  that i think just to end
#         — and tremendous intelligence doing what  he did  it was not that easy for
#                             see he did — uh yeah  he did  terribly oh but we just got
#         of laboratories in each individual state  he did  raise the issue that we had
#              terminate — the president i thought  he did  a terrible job absolutely terrible he
#              back from wisconsin the first thing  he did  he called up i said hows
#               to work mr president the president  he did  well they all did well i
#                     made it his first thing that  he did  when he was better is i
#                      there i thought hed do well  he did  great as the governor of indiana
#                           in the end its bad but  he did  have some political difficulty with it
#               seems pretty late the president so  he did  — he did it pretty late
#                       life changing but he did —  he did  a bad thing sending a letter
#                           mark — and its okay if  he did  i wouldnt — you know look
#                   i thought it was terrible what  he did  to write a letter i mean
#       issuing his stayathome order the president  he did  he spoke to me this morning
#                       close it down to china now  he did  that now he issued it on
#                        want to try one more time  he did  say in remarks to soldiers on
#                       could get up and speak and  he did  q so he said that once
#                 biden didnt write that he wished  he did  but he didnt go ahead please
#                    so i appreciate the fact that  he did  because i was called xenophobic racist
#                 a mistake im not justifying what  he did  he made a mistake he shouldnt
#             deal with the pandemic the president  he did  we had a very good talk
#                      he did uh terribly lets see  he did  — uh yeah he did terribly
#                           of — of plague so what  he did  was totally inappropriate other than that
#                    can be taking — the president  he did  q — to deal with the
#                   know its not life changing but  he did  — he did a bad thing
#                      and also on — the president  he did  what what q reuters reported today
#                              that way if he — if  he did  id have a much different type
#                     day people dont know the job  he did  i didnt even know he was
#                        speak to him about it but  he did  speak to me this morning we
#       president of ukraine foreign minister said  he did  nothing wrong and over that with
#                          id have to look at what  he did  q back to the healthcare workers
#                        the president so he did —  he did  it pretty late i mean you

# %% [markdown]
# variety of different subjects that he is referring to

# %% [markdown]
# ### Should Have: March

# %%
mar_kwic_shouldhave = make_kwic2("should have", mar_tokens, win=6)

# %%
print_kwic(sort_kwic(mar_kwic_shouldhave, order= ['R6']))
# Out:
#         focus on critical infrastructure jobs we  should have  that guidance before the president and
#                that were right here because they  should have  never allowed it to happen but
#              cdcapproved tests are moving out we  should have  2500 kits out before the end
#                american — i think every american  should have  a grateful heart first and foremost
#             talking about the ventilators but he  should have  ordered the ventilators and he had
#                          to all of them but they  should have  told us about this and i
#                you did all those divisions italy  should have  close to 400000 deaths theyre not
#                      they knew about it and they  should have  told us we could have saved
#                 next italy the president well he  should have  — you know the hospital systems
#                        up to half of the country  should have  caution before traveling and if thats
#                  epidemic the way people said we  should have  tackled flu in 1918 and they
#                          how it comes out but it  should have  been — well its like —

# %% [markdown]
# less instances in March, more opportunity for reflection in April

# %% [markdown]
# ### Should Have: April

# %%
apr_kwic_shouldhave = make_kwic2("should have", apr_tokens, win=6)

# %%
apr_kwic_shouldhave
# Out:
# [[['him', 'the', 'president', 'you', '—', 'you'],
#   'should have',
#   ['no', 'complaints', 'please', 'q', 'thank', 'you']],
#  [['the', 'world', 'and', 'we', 'think', 'that'],
#   'should have',
#   ['happened', 'so', 'well', 'let', 'you', 'know']],
#  [['at', 'a', 'group', 'of', 'people', 'that'],
#   'should have',
#   ['stopped', 'it', 'at', 'the', 'source', 'but']],
#  [['one', 'day', 'because', 'of', 'something', 'that'],
#   'should have',
#   ['never', 'been', 'allowed', 'to', 'happen', 'we']],
#  [['the', 'media', 'would', 'say', 'oh', 'you'],
#   'should have',
#   ['done', 'two', 'for', 'each', 'person', 'no']],
#  [['it', 'death', 'that', 'was', 'unnecessary', 'it'],
#   'should have',
#   ['never', 'happened', 'it', 'should', 'have', 'never']],
#  [['it', 'should', 'have', 'never', 'happened', 'it'],
#   'should have',
#   ['never', 'left', 'that', 'little', 'area', 'where']],
#  [['is', 'what', 'every', 'department', 'of', 'health'],
#   'should have',
#   ['because', 'when', 'you', 'go', 'to', 'that']],
#  [['things', 'about', 'china', 'world', 'health', 'organization'],
#   'should have',
#   ['told', 'us', 'but', 'i', 'was', 'reading']],
#  [['it', 'with', 'or', 'without', 'them', 'they'],
#   'should have',
#   ['known', 'all', 'they', 'had', 'to', 'do']],
#  [['have', 'been', 'looking', 'into', 'china', 'they'],
#   'should have',
#   ['been', 'looking', 'into', 'china', 'as', 'an']],
#  [['states', 'where', 'they', 'belong', 'where', 'they'],
#   'should have',
#   ['never', 'left', 'what', 'happens', 'if', 'youre']],
#  [['angry', 'because', 'information', 'about', 'the', 'virus'],
#   'should have',
#   ['been', 'told', 'to', 'us', 'earlier', 'and']],
#  [['same', 'thing', 'about', 'you', 'that', 'you'],
#   'should have',
#   ['warned', 'them', 'the', 'virus', 'was', 'spreading']],
#  [['that', 'they', 'didnt', 'have', 'that', 'they'],
#   'should have',
#   ['had', 'we', 'just', 'got', 'them', 'hospital']],
#  [['those', 'two', 'in', 'either', 'event', 'they'],
#   'should have',
#   ['let', 'us', 'go', 'in', 'you', 'know']],
#  [['fill', 'up', 'their', 'stockpile', 'which', 'they'],
#   'should have',
#   ['new', 'york', 'had', 'a', 'chance', 'to']],
#  [['met', 'with', 'them', 'many', 'times', 'he'],
#   'should have',
#   ['never', 'met', 'with', 'them', 'and', 'in']],
#  [['the', 'way', 'we', 'have', 'now', 'and'],
#   'should have',
#   ['—', 'the', 'private', 'sector', 'who', 'clearly']],
#  [['theres', 'other', 'tests', 'that', 'other', 'americans'],
#   'should have',
#   ['and', 'i', 'think', 'this', 'has', 'really']],
#  [['situation', 'that', 'was', 'caused', '—', 'that'],
#   'should have',
#   ['been', 'solved', 'long', 'ago', 'it', 'could']],
#  [['a', 'certain', 'country', 'did', 'what', 'they'],
#   'should have',
#   ['done', 'and', 'were', 'just', 'starting', 'to']],
#  [['states', 'who', 'didnt', 'have', 'them', 'who'],
#   'should have',
#   ['had', 'them', 'and', 'were', 'also', 'going']],
#  [['and', 'i', 'was', 'angry', 'because', 'it'],
#   'should have',
#   ['been', 'told', 'to', 'us', 'it', 'should']],
#  [['have', 'been', 'told', 'to', 'us', 'it'],
#   'should have',
#   ['been', 'told', 'to', 'us', 'early', 'it']],
#  [['been', 'told', 'to', 'us', 'early', 'it'],
#   'should have',
#   ['been', 'told', 'to', 'us', 'a', 'lot']],
#  [['the', 'bottom', 'of', 'it', 'but', 'people'],
#   'should have',
#   ['—', 'q', 'angry', 'with', 'china', 'or']],
#  [['not', 'saying', 'anything', 'im', 'saying', 'people'],
#   'should have',
#   ['told', 'us', 'about', 'this', 'they', 'should']],
#  [['have', 'told', 'us', 'about', 'this', 'they'],
#   'should have',
#   ['told', 'the', 'rest', 'of', 'the', 'world']],
#  [['bridges', 'are', 'in', 'bad', 'shape', 'they'],
#   'should have',
#   ['been', 'fixed', '25', 'years', 'ago', 'and']],
#  [['badly', 'need', 'in', 'this', 'administration', 'that'],
#   'should have',
#   ['been', 'approved', 'a', 'long', 'time', 'ago']],
#  [['president', 'well', '—', 'well', 'look', 'governors'],
#   'should have',
#   ['had', 'ventilators', 'they', 'chose', 'not', 'to']],
#  [['dont', 'know', 'what', 'theyre', 'doing', 'they'],
#   'should have',
#   ['had', 'their', 'own', 'stockpiles', 'and', 'now']],
#  [['the', 'way', 'some', 'people', 'think', 'i'],
#   'should have',
#   ['waited', 'longer', 'and', 'maybe', 'ridden', 'it']],
#  [['didnt', 'have', 'them', 'because', 'the', 'states'],
#   'should have',
#   ['had', 'them', 'no', 'one', 'who', 'has']],
#  [['something', 'that', 'frankly', 'i', 'think', 'people'],
#   'should have',
#   ['thought', 'of', 'a', 'long', 'time', 'ago']],
#  [['have', 'a', 'lot', 'of', 'things', 'that'],
#   'should have',
#   ['been', 'had', 'and', 'you', 'can', 'read']],
#  [['—', 'i', 'dont', 'think', 'the', 'ship'],
#   'should have',
#   ['been', 'stopping', 'in', 'vietnam', 'when', 'you']],
#  [['know', 'i', 'dont', 'think', 'the', 'captain'],
#   'should have',
#   ['been', 'writing', 'letters', 'hes', 'not', 'ernest']],
#  [['—', 'it', 'should', 'be', 'and', 'it'],
#   'should have',
#   ['always', 'been', 'and', 'ive', 'always', 'said']],
#  [['say', 'made', 'mistakes', 'but', 'maybe', 'i'],
#   'should have',
#   ['really', 'tried', 'to', 'delve', 'into', 'that']],
#  [['is', 'that', 'a', 'mistake', 'maybe', 'i'],
#   'should have',
#   ['been', 'able', 'to', 'realize', 'that', 'earlier']],
#  [['build', 'up', 'the', 'stockpiles', 'which', 'they'],
#   'should have',
#   ['had', 'in', 'the', 'states', 'and', 'so']],
#  [['phase', 'four', 'and', 'i', 'think', 'we'],
#   'should have',
#   ['infrastructure', 'and', 'i', 'think', 'we', 'should']],
#  [['have', 'infrastructure', 'and', 'i', 'think', 'we'],
#   'should have',
#   ['a', 'payroll', 'tax', 'moratorium', 'because', 'thats']],
#  [['to', 'the', 'united', 'states', 'and', 'they'],
#   'should have',
#   ['never', 'been', 'allowed', '—', 'this', 'should']],
#  [['have', 'never', 'been', 'allowed', '—', 'this'],
#   'should have',
#   ['never', 'been', 'allowed', 'to', 'happen', 'when']],
#  [['per', 'week', 'do', 'you', 'think', 'we'],
#   'should have',
#   ['before', 'the', 'economy', 'is', 'open', 'sir']],
#  [['system', '—', 'first', 'of', 'all', 'we'],
#   'should have',
#   ['voter', 'id', 'when', 'you', 'vote', 'you']],
#  [['voter', 'id', 'when', 'you', 'vote', 'you'],
#   'should have',
#   ['voter', 'id', 'and', 'if', 'you', 'send']],
#  [['on', 'in', 'this', 'country', 'this', 'country'],
#   'should have',
#   ['voter', 'id', 'okay', 'lets', 'do', 'another']],
#  [['they', 'would', 'have', 'known', 'and', 'they'],
#   'should have',
#   ['known', 'and', 'they', 'probably', 'did', 'know']],
#  [['your', 'staff', 'or', 'peter', 'navarro', 'himself'],
#   'should have',
#   ['told', 'you', 'about', 'the', 'memo', 'earlier']],
#  [['you', 'got', 'to', 'vote', 'and', 'they'],
#   'should have',
#   ['voter', 'id', 'by', 'the', 'way', 'if']],
#  [['worth', 'of', 'our', 'agricultural', 'product', 'that'],
#   'should have',
#   ['a', 'huge', 'impact', 'on', 'our', 'farmers']],
#  [['away', 'with', 'absolute', 'murder', 'and', 'it'],
#   'should have',
#   ['never', 'happened', 'q', 'what', 'about', 'fighting']],
#  [['have', 'sent', 'that', 'letter', 'or', 'he'],
#   'should have',
#   ['gone', 'through', 'his', 'chain', 'of', 'command']],
#  [['anybody', 'in', 'this', 'room', 'what', 'he'],
#   'should have',
#   ['done', 'and', 'im', 'sure', 'he', 'feels']],
#  [['never', 'have', 'to', 'use', 'them', 'they'],
#   'should have',
#   ['—', 'the', 'hospitals', 'the', 'states', 'should']],
#  [['have', '—', 'the', 'hospitals', 'the', 'states'],
#   'should have',
#   ['bought', 'a', 'stockpile', 'they', 'didnt', 'do']],
#  [['do', 'this', '—', 'to', 'do', 'this'],
#   'should have',
#   ['taken', '—', 'q', 'and', 'does', 'the']],
#  [['build', 'it', 'to', 'a', 'level', 'it'],
#   'should have',
#   ['taken', 'a', 'year', 'it', 'shouldve', 'taken']],
#  [['well', 'its', 'not', 'enough', 'the', 'president'],
#   'should have',
#   ['sent', 'more', 'so', 'hes', 'asking', 'for']],
#  [['say', 'hows', 'the', 'president', 'doing', 'he'],
#   'should have',
#   ['given', 'more', 'because', 'thats', 'politics', 'thats']],
#  [['theyre', 'all', 'really', 'happy', 'because', 'they'],
#   'should have',
#   ['been', 'doing', 'this', 'work', 'themselves', 'for']],
#  [['these', 'not', 'states', 'that', 'you', 'think'],
#   'should have',
#   ['those', 'stayathome', 'orders', 'in', 'place', 'the']],
#  [['recommended', '—', 'said', 'that', 'every', 'state'],
#   'should have',
#   ['stayathome', 'orders', 'right', 'now', 'do', 'you']],
#  [['happy', 'with', 'the', 'president', 'no', 'he'],
#   'should have',
#   ['given', 'us', '10000', 'thats', 'whats', 'happening']],
#  [['more', 'ventilators', 'at', 'the', 'time', 'they'],
#   'should have',
#   ['had', 'more', 'ventilators', 'they', 'were', 'totally']],
#  [['but', 'on', 'many', 'of', 'them', 'you'],
#   'should have',
#   ['a', 'picture', 'on', 'your', '—', 'on']],
#  [['should', 'be', 'called', 'voter', 'id', 'they'],
#   'should have',
#   ['that', 'and', 'it', 'shouldnt', 'be', 'mailin']],
#  [['vote', 'at', 'the', 'booth', 'and', 'you'],
#   'should have',
#   ['voter', 'id', 'because', 'when', 'you', 'have']],
#  [['most', 'vulnerable', 'by', 'now', 'nursing', 'homes'],
#   'should have',
#   ['suspended', 'the', 'entry', 'of', 'all', 'medically']],
#  [['stockpiles', 'by', 'the', 'way', 'the', 'states'],
#   'should have',
#   ['been', 'building', 'their', 'stockpile', 'we', 'have']],
#  [['all', 'this', 'equipment', 'ideally', 'those', 'states'],
#   'should have',
#   ['had', 'all', 'this', 'equipment', 'and', 'i']],
#  [['what', 'they', 'should', 'do', 'is', 'they'],
#   'should have',
#   ['—', 'long', 'before', 'this', 'pandemic', 'arrived']],
#  [['long', 'before', 'this', 'pandemic', 'arrived', 'they'],
#   'should have',
#   ['been', 'on', 'the', 'open', 'market', 'just']],
#  [['to', 'a', 'late', 'start', 'and', 'they'],
#   'should have',
#   ['pushed', 'harder', 'but', 'governors', 'and', 'other']],
#  [['made', 'a', 'deal', 'that', 'president', 'obama'],
#   'should have',
#   ['never', 'made', 'it', 'was', 'a', 'shortterm']],
#  [['youre', 'like', 'oh', 'my', 'gosh', 'i'],
#   'should have',
#   ['never', 'done', 'that', 'and', 'thats', 'the']]]

# %%
print_kwic(sort_kwic(apr_kwic_shouldhave , order=['R1']))
# Out:
#               have infrastructure and i think we  should have  a payroll tax moratorium because thats
#           worth of our agricultural product that  should have  a huge impact on our farmers
#                          but on many of them you  should have  a picture on your — on
#                            — it should be and it  should have  always been and ive always said
#          theres other tests that other americans  should have  and i think this has really
#               is what every department of health  should have  because when you go to that
#                have been looking into china they  should have  been looking into china as an
#        angry because information about the virus  should have  been told to us earlier and
#                 situation that was caused — that  should have  been solved long ago it could
#                       and i was angry because it  should have  been told to us it should
#                          have been told to us it  should have  been told to us early it
#                         been told to us early it  should have  been told to us a lot
#                    bridges are in bad shape they  should have  been fixed 25 years ago and
#           badly need in this administration that  should have  been approved a long time ago
#                        have a lot of things that  should have  been had and you can read
#                          — i dont think the ship  should have  been stopping in vietnam when you
#                    know i dont think the captain  should have  been writing letters hes not ernest
#                        is that a mistake maybe i  should have  been able to realize that earlier
#             theyre all really happy because they  should have  been doing this work themselves for
#                 stockpiles by the way the states  should have  been building their stockpile we have
#           long before this pandemic arrived they  should have  been on the open market just
#                         per week do you think we  should have  before the economy is open sir
#                  have — the hospitals the states  should have  bought a stockpile they didnt do
#                       the media would say oh you  should have  done two for each person no
#                  a certain country did what they  should have  done and were just starting to
#                     anybody in this room what he  should have  done and im sure he feels
#                  say hows the president doing he  should have  given more because thats politics thats
#                   happy with the president no he  should have  given us 10000 thats whats happening
#                      have sent that letter or he  should have  gone through his chain of command
#                   that they didnt have that they  should have  had we just got them hospital
#                   states who didnt have them who  should have  had them and were also going
#             president well — well look governors  should have  had ventilators they chose not to
#                 dont know what theyre doing they  should have  had their own stockpiles and now
#               didnt have them because the states  should have  had them no one who has
#               build up the stockpiles which they  should have  had in the states and so
#                more ventilators at the time they  should have  had more ventilators they were totally
#          all this equipment ideally those states  should have  had all this equipment and i
#                      the world and we think that  should have  happened so well let you know
#                        phase four and i think we  should have  infrastructure and i think we should
#                     it with or without them they  should have  known all they had to do
#                   they would have known and they  should have  known and they probably did know
#                   those two in either event they  should have  let us go in you know
#                one day because of something that  should have  never been allowed to happen we
#                 it death that was unnecessary it  should have  never happened it should have never
#                 it should have never happened it  should have  never left that little area where
#              states where they belong where they  should have  never left what happens if youre
#                      met with them many times he  should have  never met with them and in
#                    to the united states and they  should have  never been allowed — this should
#                   have never been allowed — this  should have  never been allowed to happen when
#                 away with absolute murder and it  should have  never happened q what about fighting
#                 made a deal that president obama  should have  never made it was a shortterm
#                          youre like oh my gosh i  should have  never done that and thats the
#               fill up their stockpile which they  should have  new york had a chance to
#                      him the president you — you  should have  no complaints please q thank you
#                         to a late start and they  should have  pushed harder but governors and other
#                    say made mistakes but maybe i  should have  really tried to delve into that
#                well its not enough the president  should have  sent more so hes asking for
#              recommended — said that every state  should have  stayathome orders right now do you
#                        at a group of people that  should have  stopped it at the source but
#             most vulnerable by now nursing homes  should have  suspended the entry of all medically
#                             do this — to do this  should have  taken — q and does the
#                           build it to a level it  should have  taken a year it shouldve taken
#                   should be called voter id they  should have  that and it shouldnt be mailin
#                  these not states that you think  should have  those stayathome orders in place the
#            something that frankly i think people  should have  thought of a long time ago
#     things about china world health organization  should have  told us but i was reading
#             not saying anything im saying people  should have  told us about this they should
#                     have told us about this they  should have  told the rest of the world
#              your staff or peter navarro himself  should have  told you about the memo earlier
#                         system — first of all we  should have  voter id when you vote you
#                       voter id when you vote you  should have  voter id and if you send
#                  on in this country this country  should have  voter id okay lets do another
#                         you got to vote and they  should have  voter id by the way if
#                        vote at the booth and you  should have  voter id because when you have
#                      the way some people think i  should have  waited longer and maybe ridden it
#                    same thing about you that you  should have  warned them the virus was spreading
#                          the way we have now and  should have  — the private sector who clearly
#                      the bottom of it but people  should have  — q angry with china or
#                      never have to use them they  should have  — the hospitals the states should
#                      what they should do is they  should have  — long before this pandemic arrived

# %% [markdown]
# the rare ocassions where he says I, he says "Maybe I should have" or "some people think I should have"

# %% [markdown]
# ### You See: April

# %%
apr_kwic_yousee= make_kwic2("you see", apr_tokens, win=6)

# %%
print_kwic(sort_kwic(apr_kwic_yousee  , order=['R1']))
# Out:
#                    low end you were shocked when  you see  100 and 120000 and 200000 people
#         president theyre very sobering yeah when  you see  100000 people thats a — and
#                      new jersey — 29 people when  you see  173 people died in new york
#                      even thought of it and then  you see  6 million people unemployed unemployment numbers
# unemployed unemployment numbers get released and  you see  6 million people and its an
#                 can businesses expect to have do  you see  a phase five a phase six
#                  your question q mr secretary do  you see  a need for a phase four
#            the president was talking about where  you see  a flattening out of cases and
#                          at a very low level and  you see  a couple at a higher level
#                       you look at that graph and  you see  all of the — the bumps
#                          — they were tough — but  you see  all of those levels you know
#                       and all of the things that  you see  can you imagine if we had
#               nurses the doctors the people that  you see  celebrating the president yes q sorry
#                   though as a health expert when  you see  folks congregate and are you worried
#                     redfield and dr birx what do  you see  for the fall is it going
#                        what goes on in spain and  you see  france is having a very hard
#                      to go further than that but  you see  her story you know her story
#                    is the exact opposite of what  you see  here which is a gradual gradation
#                    at us compared to others when  you see  how weve taken testing from a
#             virus — this horrible horrible virus  you see  how terrible it is especially when
#                        to find out you know when  you see  hundreds of thousands of applications —
#                       be a good thing because as  you see  in terms of what this vicious
#              the governor were recommending — as  you see  in the charts were recommending certain
#                   the pieces of equipment now so  you see  in the system — i just
#              inside or almost a cleaning because  you see  it gets in the lungs and
#           satisfied with — the president because  you see  it in the charts i mean
#                             with us i mean — and  you see  it look i dont understand when
#                          — i really think — look  you see  it with the stock market the
#                         were going to have a lot  you see  it with general motors you see
#                   you see it with general motors  you see  it with other companies that are
#            theres a tremendous pentup demand and  you see  it this week — i mean
#          they develop drugs like the antibiotics  you see  it antibiotics used to solve every
#                   thats why the message — before  you see  it before you have to see
#                      a place like new york where  you see  it goes up at peak and
#                      them thats the beauty of it  you see  it can help them but its
#                 it comes which is coming quickly  you see  it you see it as sure
#                     is coming quickly you see it  you see  it as sure as you can
#                      faced before you all see it  you see  it probably better than most were
#                     fauci said if you wait until  you see  it its too late q and
#               and there are different impacts as  you see  new york is very different from
#                    president well i would but if  you see  new york — i believe the
#                   and these are the shields that  you see  on television quite a bit and
#                       lot but its not because as  you see  on the board from yesterday as
#                    theyve learned a lot you know  you see  people picketing a little bit and
#                 what goes through your mind when  you see  photographs of crowded beaches in florida
#  and increasing the diagnostic capabilities that  you see  presented here thank you the vice
#                           because i see — i know  you see  reports every day of countries that
#                      its good people like — that  you see  sitting to my right theyve been
#                            27 feet but — so when  you see  somebody do that get out of
#               millions of workers on the payroll  you see  states are starting to open up
#                         want to get back to work  you see  that whether its a demonstration or
#                    a unanimous vote how often do  you see  that but the legislation passed by
#           a very very powerful important process  you see  that people are getting very anxious
#                    think their data is good when  you see  that do you think that —
#              i described next slide so hopefully  you see  that weve brought cdc and their
#                    just mentioned — is that when  you see  that thats where you want your
#                         its — its very smart and  you see  that in a case like a
#              dotted line are getting bigger when  you see  that you know the model has
#                   smart guy he loves his country  you see  that i mean he fought like
#                         look out in new york now  you see  that its in long island and
#                    at the first three lines when  you see  the word surface were talking about
#                   sun hes talking about heat and  you see  the numbers so thats it thats
#                 the president yeah okay fine but  you see  the number — thanks thanks these
#                      this is one more step where  you see  the army corps of engineers where
#          the american people everywhere you look  you see  the patriotism of our people shining
#                        thats why — and thats why  you see  the stock market — i mean
#                           hope as you look on as  you see  the progress thats made on the
#               theyve had it sometimes its brutal  you see  the prime minister seems to be
#                            and if i may where do  you see  the use of something like immunity
#                    have had potentially — i mean  you see  the charts nobody knows nobody will
#                in the future were getting closer  you see  the numbers were getting much closer
#           into providing the ventilators so when  you see  the ventilator numbers going out theyre
#                       weeks as the surge goes on  you see  the chart we havent hit the
#             better job than that especially when  you see  the 22 million number and i
#                       it was more than that when  you see  the kind of numbers that were
#                   the covid hotspots as you know  you see  them all over i spoke —
#                          a lot of people love me  you see  them all the time right i
#               every individual that they serve —  you see  them on the tv you see
#                           you see them on the tv  you see  them in the emergency room you
#                   wrote back in january when did  you see  them and how does that —
#                          — until we get those if  you see  them on the internet do not
#                 — they walk into those hospitals  you see  them putting on their gear and
#             be this years respiratory season and  you see  theres a peak there up over
#                      packed all the time and now  you see  theres nobody you look at other
#                       please q thank you sir did  you see  these memos that reportedly peter navarro
#                     to contain and you know when  you see  this a lot of people have
#                     get your response to that do  you see  this an advancement of the missile
#                      doctors im curious if — did  you see  this information out of the cdc
#                        and what it meant okay so  you see  this confidence interval so heres the
#                terms of reopening the economy do  you see  those two — the president well
#                    to be encouraged to know when  you see  those numbers on the vast majority
#       started small with the commercial partners  you see  today right now we have 73
#                 other countries need them i mean  you see  uk needs them badly france needs
#                    cities are doing very well as  you see  very well at this early stage
#                      thats what were going to do  you see  we have very good surveillance systems
#                      workers and if you look and  you see  we have a lot of people
#       the medical center building business where  you see  we built many hospitals — numerous
#           everybody working on the ventilators —  you see  what weve done there — have
#                    this has been pretty bad when  you see  what has happened in new york
#                     now they bring it up because  you see  what happened so now — but
#                        to start off with so when  you see  what he said about the second
#             said about the second amendment when  you see  what other states have done —
#                           do any form of ban and  you see  what happened to italy you see
#                   you see what happened to italy  you see  what happened to spain you see
#                   you see what happened to spain  you see  what happened to france whos guidance
#             because look the hospitals need help  you see  what theyve gone through and the
#                   see them in the emergency room  you see  what theyre up against — this
#          is sealed certified and everything else  you see  what you have to do with
#                             it is it is but then  you see  what starts to happen and the
#                   to our country in recent years  you see  what happens its witch hunt after
#                         to a very late start and  you see  what happens when you get off
#              having a very good relationship and  you see  what just happened in central park
#                    its important — you know look  you see  what happened with boris johnson you
#             see what happened with boris johnson  you see  what happened with others i think
#                is going to do fantastically well  you see  whats going on there is a
#                           then all of a sudden —  you see  whats going on they want to
#          does anybody really believe that number  you see  whats going on over there does
#                 and thats exactly what its doing  you see  whats happening and where we are
#                       future having to do with —  you see  whats happened the farmers got hurt
#                new york i was watching louisiana  you see  whats going on the numbers are
#            prematurely but thats the first thing  you see  when you start to see the
#                       — not only testing who did  you see  where were you how many people
#                   you dont need funding they pay  you see  you know because right now —
#                         go ahead please q — when  you see  yourself getting back to campaigning then
#                     is to ensure the states that  you see  — the 48 across the bottom

# %% [markdown]
# no clear trend

# %%
apr_kwic_hedidnt= make_kwic2("he didnt", apr_tokens, win=6)

# %%
print_kwic(sort_kwic(apr_kwic_hedidnt , order=['R1']))
# Out:
#                       the fake news is saying oh  he didnt  act fast enough well you remember
#                         — we talked to him today  he didnt  bring that up today q havent
#                     the president no he didnt no  he didnt  defy me at all thats your
#                    me at all thats your language  he didnt  defy me q well i mean
#                   would say wheres the 11th time  he didnt  do his job trump didnt do
#                        he was supposed to do and  he didnt  do very well with it but
#                 rights activist but he said that  he didnt  do that and he was —
#                    was — the president you think  he didnt  do it are you on his
#                           go crazy like he has —  he didnt  even know what the hell the
#                        you dont need the ban you  he didnt  go crazy like he has —
#                              ban was but he — so  he didnt  go crazy but he did say
#                        that he wished he did but  he didnt  go ahead please back q sure
#                    literally — he had days where  he didnt  go to bed he didnt go
#                         where he didnt go to bed  he didnt  go to sleep he called —
#                 should not have written a letter  he didnt  have to be ernest hemingway he
#                     have said quite what he said  he didnt  have to resign but he felt
#                 would you say thats correct mike  he didnt  know the vice president he didnt
#                 he didnt know the vice president  he didnt  know they were available the president
#           know they were available the president  he didnt  know and mike doesnt like to
#                 less controversial than i am but  he didnt  know about it and if he
#                      needs it hes been waiting —  he didnt  know he was going to get
#                          a friend of mine — said  he didnt  know we had so many countries
#                         scam on him the fbi said  he didnt  lie and muellers people wanted him
#                    made per joe biden sleepy joe  he didnt  make those statements but somebody did
#           tested positive and unfortunately he —  he didnt  make it its a very —
#                   president xi the other day and  he didnt  mention that we didnt mention that
#                       president no no he didnt —  he didnt  misspeak q is that federal stockpile
#                     thats okay q so youre saying  he didnt  need to go to south korea
#                     say that i appreciate it and  he didnt  need it but we were ready
#                      it clear — the president no  he didnt  no he didnt defy me at
#                  of as an example governor hogan  he didnt  really know he really — it
#                    going to be there forever and  he didnt  really know that he thought that
#                  today q yeah the president well  he didnt  really drop out he didnt really
#                    well he didnt really drop out  he didnt  really — what about his delegates
#              interviewed he said — the president  he didnt  say anything last saturday q —
#              just to straighten that out because  he didnt  say it was a big —
#                         no — excuse me excuse me  he didnt  say a lot he said we
#                        me say he — the president  he didnt  say a lot he didnt say
#                     president he didnt say a lot  he didnt  say you did a good job
#                 states — the president well what  he didnt  say is — okay let me
#                        okay let me tell you what  he didnt  say two very good friends of
#                      did trump do were not happy  he didnt  send us enough ventilators because thats
#                       by two friends of mine but  he didnt  tell you that now the governor
#                       stupid to be in command if  he didnt  think that writing that letter was
#        maryland didnt really understand the list  he didnt  understand too much about what was
#             force him into saying something that  he didnt  want to say so i appreciate
#                       i had heard he did because  he didnt  want to cause any disturbance for
#                           a state — it wasnt him  he didnt  write it im sure he doesnt
#                   said that — the president well  he didnt  write anything look he has people
#                   to that sir the president okay  he didnt  write that that was done by
#           misspeak yesterday the president no no  he didnt  — he didnt misspeak q is

# %% [markdown]
# no clear pattern

# %% [markdown]
# ### We will: March

# %%
mar_kwic_wewill= make_kwic2("we will", mar_tokens, win=6)

# %%
print_kwic(sort_kwic(mar_kwic_wewill , order=['R1']))
# Out:
#                        of our people i know that  we will  achieve victory and quickly return to
#                     fault we want to protect and  we will  all of the things that a
#                    to making that data public so  we will  all know dr birx were committed
#                something that i hope — hopefully  we will  all have made the right moves
#                    earth and in the coming weeks  we will  all have to make changes and
#                     than we were even before and  we will  also have apparatus in place that
#                     on a program to address that  we will  also be working with small businesses
#                    put in a great healthcare and  we will  always — i will say this
#                         is yes and the answer is  we will  always maintain a solvent social security
#                  listens to the governors and so  we will  assess at the end of the
#                 will only do it with preexisting  we will  back preexisting conditions okay thank you
#          this whole nightmare will end therefore  we will  be extending our guidelines to april
#                    to slow the spread on tuesday  we will  be finalizing these plans and providing
#                      can expect that by june 1st  we will  be well on our way to
#         rebound with astonishing force and speed  we will  be stronger than ever and we
#                      all those changes of ppe so  we will  be implementing that this week which
#                       with all that were doing —  we will  be tomorrow at the hospital boat
#                         its also big for jobs so  we will  be able to handle united and
#               a robust menu of courses virtually  we will  be adding that information to our
#      letter to americas governors describing how  we will  be using the data to update
#                      for those that dont have it  we will  be having the checks in the
#                will never be a supplicant nation  we will  be a proud prosperous independent and
#               will embrace commerce with all but  we will  be dependent on none above all
#            still working on our backlog although  we will  be in touch with the laboratories
#               the disease across the country and  we will  be using data to recommend new
#    and other personal protective equipment which  we will  be distributing to medical hotspots were
#                       to go with their local dmv  we will  be announcing the new deadline very
# whove submitted major disaster declarations that  we will  be reviewing them in an expeditious
#                       we may quarantine — i mean  we will  be quarantine — quarantining many people
#               right thing and i think ultimately  we will  be rewarded because of the decision
#                        time we all know that but  we will  be totally victorious we will then
#                      a great burden right now so  we will  be talking about that further but
#                     — its an invisible enemy and  we will  be successful — very successful —
#           hope this morning has been informative  we will  be back again tomorrow and i
#                are you thinking of the president  we will  be helping the airline industry we
#             will be helping the airline industry  we will  be helping the cruise ship industry
#                  i cant state it strongly enough  we will  be helping small businesses thats where
#                          of the — of the country  we will  be helping small businesses q these
#                         it its prepared to go so  we will  be invoking the defense production act
#                       that would be the case and  we will  be — its being signed its
#               increase that to 300 billion which  we will  be doing now let me just
#                  industry and well be doing that  we will  be doing that this is not
#                      do what were doing and what  we will  be doing admirar giroir and let
#                         people per day we will —  we will  be at the tens of thousands
#                     is our total sample size and  we will  be getting more data from countries
#                  and as of midnight monday night  we will  be suspending all travel from the
#                            let me say as i close  we will  be back in the morning tomorrow
#                    say that at 5 oclock tomorrow  we will  be detailing the progress that our
#                 dont want people to be surprised  we will  be doing a technical correction on
#               speaker and i have acknowledged it  we will  be working starting immediately the airlines
#                  we will succeed we will prevail  we will  be very very successful and well
#                its a very important industry and  we will  be helping them and we will
#                      we will be helping them and  we will  be helping the airline industry if
#                     if we start doing this today  we will  be ready next year for any
#                  care of the american public and  we will  be taking care of the american
#                  the president well i think what  we will  be doing is having a news
#            informed each of these guidelines but  we will  be providing that this evening in
#                     thank you all for being here  we will  be back here tomorrow and well
#                         — well find that out but  we will  be testing everyone on the ship
#                  be testing everyone on the ship  we will  be quarantining as necessary but with
#                          midst of a busy day and  we will  be engaged im confident in the
#                          dr birx speak to this —  we will  be meeting tomorrow here at the
#                   will be issuing a new guidance  we will  be directing all federal government agencies
#                   you as the vice president said  we will  be focusing all of our state
#               for the country the vice president  we will  be back tomorrow as i said
#                think its a terrific question and  we will  bring secretary betsy devos here tomorrow
#    have capabilities from roche diagnostics that  we will  bring into our facilities this weekend
#                    have to defeat this virus and  we will  but it cost me billions and
#               there for everyone to see together  we will  care for our fellow citizens and
#               ill promise the american people is  we will  collect the data and then make
#                     and thats what weve done and  we will  continue to do it until our
#               mercy arrived in los angeles today  we will  continue to focus resources and supplies
#                 what were going through and what  we will  continue to be going through for
#                      the spread in new york city  we will  continue to surge resources the president
#    best scientists and medical professionals and  we will  continue to do so until we
#                 resources ive made it clear that  we will  continue to support the administrations comprehensive
#               the presidents direction we will —  we will  continue to do whatever it takes
#               whos in session right now actively  we will  continue to have conversations with the
#           public and at the presidents direction  we will  continue not only a wholeofgovernment approach
#                 focus on the most vulnerable and  we will  continue to urge every american to
#                   the governor a few moments ago  we will  continue to work very closely with
#         very closely with his administration and  we will  continue to put the health and
#             relationship with the fda is ongoing  we will  continue that as we develop more
#              if we follow this prescription then  we will  decrease the number of people who
#                number of people who are impacted  we will  decrease the number of people who
#          contain and ultimately defeat the virus  we will  defeat the virus it will also
#         single most important asset and together  we will  defeat this invisible curse — this
#                 rally together as one nation and  we will  defeat the virus and were going
#                will of our nation is unbreakable  we will  defeat this threat when america is
#        availability of ventilators and on monday  we will  detail some very encouraging news for
#                    the bottom line and quickly —  we will  do what we have to do
#             power of the american government and  we will  do that and thats what weve
#                    saying that the answer is yes  we will  do those tests because i think
#                 hhs to answer these requests but  we will  do whatever is necessary to get
#                    some un — really good promise  we will  do so in a way that
#                 find that we need something that  we will  do that and you dont know
#              a very exciting news conference and  we will  do it as quickly as we
#         government to defeat the coronavirus and  we will  do whatever it takes and were
#                    we look at this and literally  we will  do everything that we can to
#                       and whatever we need to do  we will  do q mr vice president thank
#                    — is very very important here  we will  do the best we can eamon
#                     but within the next 100 days  we will  either make or get in some
# proud prosperous independent and selfreliant nation  we will  embrace commerce with all but we
#        dedicate ourselves today the more quickly  we will  emerge on the other side of
#             like hospitals and nursing homes and  we will  ensure that we can give cities
#            the need for additional resources and  we will  evaluate those very carefully and i
#                it out because its something that  we will  face were not facing it now
#                       were not facing it now but  we will  face — our chinese colleagues are
#                 if we continue with that process  we will  fail in containing this virus so
#                        in and we share the facts  we will  flatten the curve and we will
#                  have a good relationship and so  we will  follow the news as youre bringing
#             people in this country praying daily  we will  get through this and get back
#                      going on so its likely that  we will  get whats called an efficacy signal
#               the prayers of the american people  we will  get this done we will —
#                    q thank you for being patient  we will  get to you we have so
#         one last encouragement to every american  we will  get to that day quicker if
#                    i want americans to know that  we will  get through this challenge the hardship
#      because of the hospitalization records what  we will  get to as a country with
#                 which are doing testing for whom  we will  get data this week to give
#                   lets pull in this together and  we will  get through it i promise you
#                our state and local officials and  we will  get through this and we will
#                     we will get through this and  we will  get through this together thank you
#                   the strength of our people and  we will  get through this all together we
#                 but well refer that question and  we will  get you an answer from the
#          what were those occasions the president  we will  give you that notification well let
#                   really the fate of our victory  we will  have a great victory we have
#                 because weve learned so much but  we will  have lost a lot of people
#                   will be stronger than ever and  we will  have learned so much where something
#                           we can do with it that  we will  have some sort of therapy thatll
#                 delay i will sign it immediately  we will  have a signing and itll be
#                          by the end of next week  we will  have a very simple process where
#            our expectation is within three weeks  we will  have direct payments out where we
#               controlled trials of drugs so that  we will  have a menu of drugs that
#            testing even though probably by today  we will  have done more tests than south
#                        period and on top of that  we will  have direct deposit checks of roughly
#              of population infected and you know  we will  have vaccines most likely by the
#              of california was just received and  we will  have it approved very quickly well
#        and we remain increasingly confident that  we will  have the ventilators that we need
#                 great people of this country and  we will  have things worked out i think
#                            need it and we will —  we will  have it all completed signing it
#      all of the individual hospital laboratories  we will  have that upcoming in the next
#                    were going to be helping them  we will  have a very powerful airline industry
#                       have to knock out this and  we will  have an economy — i actually
#                     enough and if its not enough  we will  have it by the time we
#                      as i mentioned as of monday  we will  have more than 2000 labs coming
#                     per week and maybe even more  we will  have 19 million of these highthroughput
#              up now implemented during this week  we will  have the capability of testing tens
#                     roll out over this next week  we will  have a spike in our curve
#                 that sir the vice president well  we will  have updated guidelines tomorrow morning for
#                     point early in the week that  we will  have a website that goes up
#              countries on all of those maneuvers  we will  have noncalifornia residents who will be
#               president was referring to is that  we will  have people that test positive and
#           can access tests those are discussions  we will  have tomorrow and be able to
#             will protect our most vulnerable and  we will  heal our land and now for
#             will protect the most vulnerable and  we will  heal our land with that let
#             will protect our most vulnerable and  we will  heal our land thank you mr
#              can protect our most vulnerable and  we will  heal our land the president thank
#                        are in big trouble so now  we will  hear from our great secretary of
#                     that are friends of ours and  we will  help those countries were in a
#        continue learning can happen anywhere and  we will  help make sure it does we
#                    the economy was in good shape  we will  help them and their employees get
#                   iran and many of the countries  we will  help and were willing to as
#                      so remember what i said and  we will  if we have to call congress
#        private payroll in small businesses where  we will  immediately make loans that will supply
#          businesses that have cash flow problems  we will  issue guidelines youll be able to
#         white house coronavirus task force today  we will  issue new guidance from the cdc
#               will get through this all together  we will  just get through it so much
#              whats called an efficacy signal and  we will  know whether or not it actually
#                     incredible job if we do that  we will  let you know but its pretty
#                      to the actual new cases and  we will  let you know when we have
# president said eligibility requires worker retention  we will  maintain the people eligible well maintain
#                  on bipartisan support we will —  we will  make sure that the economy recovers
#                 in the country are precisely how  we will  make coronavirus tests available for your
#                       and as we learn about that  we will  make advice about travel but right
#                    as few deaths as possible and  we will  meet again tomorrow for some statistics
#      a teleconference with the nations governors  we will  meet at the national response coordination
#                       of people who will die and  we will  more quickly get to the end
#               been very special — something that  we will  never forget that the history books
#           should demonstrate clearly to all that  we will  not hesitate to use the full
#                          get this done we will —  we will  not only — we will not
#                             — we will not only —  we will  not only slow the spread well
#              and supplies because they know that  we will  not hesitate to invoke the dpa
#                some people are doing very simply  we will  not allow anyone to exploit the
#                     love them were with them and  we will  not let them down thank you
#                no getting close during this time  we will  not enforce applicable hipaa penalties so
#             testings for roche and thermo fisher  we will  now have access in the days
#                  can get a great healthcare plan  we will  only do it if we have
#                   it have a great healthcare but  we will  only do it with preexisting we
#                         the — in the near future  we will  outline a more detailed package for
#                          a few moments we will —  we will  outline community guidance that dr birx
#      prioritize our testing to hospital patients  we will  over the next few weeks be
#                    we will flatten the curve and  we will  overcome this situation so finally my
#  and shared sacrifice and national determination  we will  overcome the threat of the virus
#               follow this prescription we will —  we will  overcome the coronavirus as dr fauci
#                        in a nursing home and now  we will  pay for labs to go out
#                              us to get rid of it  we will  prevail together its very important from
#           love and determination we will succeed  we will  prevail we will be very very
#             and as governors make these requests  we will  process them bring them to the
#        support to students families and teachers  we will  propose congress provide micro grants to
#                     that we will slow the spread  we will  protect our most vulnerable and we
#                       do we will slow the spread  we will  protect the most vulnerable and we
#                     that we will slow the spread  we will  protect our most vulnerable and we
#              enduring a great national trial and  we will  prove that we can meet the
#          president is 100 percent committed that  we will  provide whatever tools we need that
#        these critical changes and sacrifices now  we will  rally together as one nation and
#                          will win and when we do  we will  rebound with astonishing force and speed
#                         it where you can find it  we will  reimburse you if you buy medical
#                    have done a fantastic job and  we will  see you all tomorrow thank you
#                      it started two days ago but  we will  see what happens i want to
#                  early results that are good but  we will  see and thats going i think
#                   now in a highspeed platform so  we will  see the number of people diagnosed
#                        for over the next 15 days  we will  see a dramatic difference and we
#                    have not reached our peak now  we will  see more cases and we will
#                       we will see more cases and  we will  see more suffering and death predominantly
#                 the coronavirus as dr fauci said  we will  see more cases unfortunately we are
#             capacity over the next several weeks  we will  see increasing demand and were trying
#                 american people i just know that  we will  slow the spread we will protect
#                            do all that we can do  we will  slow the spread we will protect
#                        this i have no doubt that  we will  slow the spread we will protect
#                          we had this great — and  we will  soon have again because i think
#            focusing in on specific locations now  we will  start shipping gear stuff tomorrow we
#          will start shipping gear stuff tomorrow  we will  start deploying officers tomorrow and tuesday
#              and hope and love and determination  we will  succeed we will prevail we will
#                   believe in you to our teachers  we will  support you and help you you
#                 talking about the same thing yes  we will  test that person because i think
#                      out of our country but yeah  we will  test those people okay thank you
#                but we will be totally victorious  we will  then get our economy up to
#                      critical we can learn — and  we will  turn a corner on this virus
#                   later this summer early fall —  we will  unveil another package of tax cut
#           the president has reflected many times  we will  use the defense production act if
#                         to make sure as ive said  we will  use all the powers we have
#                     suggested we are trying to —  we will  use assistance to unpaid sick leave
#                 need to provide to the useconomy  we will  use all our tools working very
#        bipartisan agreement on the spending deal  we will  use the same approach to work
#                 its a very devastating thing but  we will  vanquish this virus and its —
#                     back to cdc these results so  we will  very quickly get those results the
#                     easter q thats april 12th so  we will  watch and see what happens the
#            the eternal light of american courage  we will  win and when we do we
#                 care for our fellow citizens and  we will  win this war and well win
#                            we win this war — and  we will  win the war we want to
#                     solved and it will be solved  we will  win and there will be a
#                when were finished with the virus  we will  win we will win and when
#                       with the virus we will win  we will  win and when that victory takes
#              all across this nation im confident  we will  with that dr tony fauci for
# a tremendous breakthrough tremendous breakthrough and  we will  work toward a muchneeded vaccine in
#                  being the highest level — which  we will  work with and weve been working
#  an unprecedented challenge unprecedented and so  we will  work to increase the supplies of
#                    in the list of countries that  we will  you could say ban — or
#                     people we will get this done  we will  — we will not only —
#                     is to have a situation where  we will  — we do have disparities in
#                         things if we need it and  we will  — we will have it all
#                   know whether or not urgent but  we will  — yeah we do have targets
#                     no i havent seen the article  we will  — we are making a lot
#    additional orders at the presidents direction  we will  — we will continue to do
#                 from thousands of people per day  we will  — we will be at the
#            the second step on bipartisan support  we will  — we will make sure that
#              safe if we follow this prescription  we will  — we will overcome the coronavirus
#                leadership today in a few moments  we will  — we will outline community guidance

# %% [markdown]
# ### We will: April

# %%
apr_kwic_wewill= make_kwic2("we will", apr_tokens, win=6)

# %%
print_kwic(sort_kwic(apr_kwic_wewill, order=['R1']))
# Out:
#       need certain authorities from the treasury  we will  accommodate that so were — were
#                    anthony the 100000 and i hope  we will  all right so today the department
#                    if they need to remain closed  we will  allow them to do that and
#                the last four weeks is incredible  we will  also continue to expand our testing
#                    lee zeldin out in long island  we will  also be delivering another 200000 n95
#         address volatility in global oil markets  we will  always protect our servicemen and servicewomen
#                    ship we said if its necessary  we will  and we did there were military
#                       going down — which i think  we will  and i feel certain that we
#                       long that will be and then  we will  assess it and then we will
#                   to have in place and hopefully  we will  at the time that we then
#      deposit information and within several days  we will  automatically deposit the money into your
#           the frontline and first responders but  we will  be rolling that out much more
#                 as we talked about earlier today  we will  be able to supply every state
#                    you an idea the supplies that  we will  be providing to states — the
#                 of the numbers for exactly where  we will  be were north of 5 million
#                   point next fall or next winter  we will  be prepared to deal with it
#                       saying is that in the fall  we will  be much much better prepared to
#                if they are asymptomatic and that  we will  be able to deploy resources appropriately
#              that shake shack returned the money  we will  be putting out some faqs there
#                  have more results this week but  we will  be transparent about those results because
#                      them — many academics — and  we will  be including that information and the
#                  on the clinical trials and when  we will  be getting a readout of that
#                           three x four x so that  we will  be absolutely over prepared when the
#           also today informed the governors that  we will  be deploying cdc teams to every
#                  every one of the governors that  we will  be deploying teams we think of
#                        want to comment on it but  we will  be saving that for another time
#                            could get to and we —  we will  be lower than that number anywhere
#                  thats a great question and what  we will  be doing is monitoring how much
#                       what we hope and i believe  we will  be successful if we carefully do
#                    of the american public — that  we will  be able to — and it
#                 answer is it is conceivable that  we will  be able to do that i
#                     do if we see something wrong  we will  be expressing ourselves very strongly please
#                     the wide open in other cases  we will  be doing that so well be
#                        go the way were going now  we will  be significantly less than the lowest
#                      best tests in the world and  we will  be working very much with the
#                 them by wednesday — on wednesday  we will  be launching at irsgov click on
#            problem than a mechanical problem but  we will  be making a determination on that
#                       you all a good evening and  we will  be back tomorrow and — q
#                   way so were helping mexico out  we will  be reimbursed in a form sometime
#               anything and yet its very valuable  we will  be reimbursed in the future —
#                   rather than a small bounce but  we will  be back and i think —
# importantly our dedicated healthcare workers that  we will  be there to meet that need
#            them with very lowgrade symptoms what  we will  be triangulating for you is the
#                   things dont happen but i think  we will  be sooner rather than later but
#                            say it q do you think  we will  be on track for that by
#             providing that data very shortly but  we will  be doing that analysis the president
#                     dollars out and so this week  we will  be putting out another 30 billion
#                         we need it for the virus  we will  be using it for that theyd
# the hardesthit industries were saving industries  we will  be — youll be seeing it
#                  prevail we have learned so much  we will  be stronger than ever and i
#                  acute care over the coming days  we will  be making a push to the
#             manhattan and east orange new jersey  we will  be informing the governor of louisiana
#          initiate the fourth mission in michigan  we will  be providing the people of michigan
#         — the commonwealth of massachusetts that  we will  be helping them in their efforts
#                       its — its a terrible thing  we will  be seeing you soon well keep
#                 exxon mobil i informed them that  we will  be making space available in the
#                       can be found at sbagov and  we will  be updating these resources regularly our
#        the american economy and american workers  we will  be doing that q secretary mnuchin
#                           a yes answer so that —  we will  be doing that and also we
#                      will be doing that and also  we will  be staffing it so the federal
#                    texas and weve told them that  we will  be staffing those hospitals again above
#                      love new york and every day  we will  be with you and it could
#                your struggle is our struggle and  we will  beat this virus we will beat
#                      and we will beat this virus  we will  beat it together i also want
#                       i think as we move forward  we will  become more and more protective of
#                      i was glad to announce that  we will  begin to reopen our national parks
#                    we will heal our citizens and  we will  care for our neighbors and we
#            magnificent destiny that we share and  we will  carry our nation forward to new
#                             so i think we will —  we will  come up with things as time
#          deaths with mitigation its looking like  we will  come far under even these lowest
#                possible to develop like this and  we will  conquer the disease and restore our
#       rather large drug development business and  we will  continue to work with our colleagues
#         in the most critically vulnerable states  we will  continue to see mortality and deaths
#    have increased these interdiction efforts and  we will  continue to outreach and do —
#                  end users of these products and  we will  continue to do — make all
#                      good job but weve done more  we will  continue to work with governors to
#           cases hopefully that will continue and  we will  continue to make great progress these
#                to keep their communities fed and  we will  continue to work with the cdc
#                        the point of the need and  we will  continue to do just that so
#                they need and americans have jobs  we will  continue — at the department and
#         to safeguard our great american citizens  we will  continue to use every power every
#                 are able to access needed credit  we will  continue working around the clock as
# malign activities under president trumps leadership  we will  continue to execute our maximum pressure
#               to fight the spread of coronavirus  we will  continue to execute the presidents counternarcotics
#                             have a job to do and  we will  continue to do it defend the
#                  patriot we will win this battle  we will  defeat this enemy and we will
#              were the united states military and  we will  defend our country regardless of the
#                continue to take the posture that  we will  defer to state and local health
#                      shows up in four months and  we will  deliver on that promise q so
#                town or a specific community here  we will  do — and thats what the
#                    than they would have been and  we will  do that we have tremendous talent
#    to create broadbased lending facilities which  we will  do so so our expectation is
#                   but this will be an assessment  we will  do as interagency team we will
#                       were trying to do and what  we will  do in the form of mitigation
#               the governors plans for next month  we will  easily double that 4 million number
#                 with and has been persistent and  we will  emphasize to the american people again
#               people who have been so incredible  we will  end this plague and together we
#                    and also early in the morning  we will  end that grant very quickly but
#                         line as we started and —  we will  end with its communities that will
#                         and the grace of our god  we will  endure we will overcome we will
#                devotion of our people we believe  we will  experience far fewer deaths than even
#        this could happen were building thousands  we will  fairly soon be at a point
#                      to make sure that they know  we will  find a way to pay for
#                     all conditions but we will —  we will  get this done were very close
#              feel confident that sooner or later  we will  get to the point — hopefully
#                      all together and we can and  we will  get through this with a wholeofamerica
#                       modeling this and we are —  we will  get the data to actually look
#                          weve said it will end —  we will  get over coronavirus but there will
#                       that over a period of time  we will  get a good vaccine that we
#                        to keep on keeping on and  we will  get through this america we will
#                 we will get through this america  we will  get through the coronavirus to that
#                  the country are stepping up and  we will  get through this together at sba
#                       will look at the facts and  we will  give people recommendations based on the
#      clear in understanding the certification so  we will  give people the benefit of the
#          us public health service announced that  we will  give an option to states to
#         louisiana john bel edwards tomorrow that  we will  give him access to our va
#                       when we get back to normal  we will  go back gradually to the point
#                      days to slow the spread and  we will  hasten the day that we heal
#                        as we continue to do that  we will  hasten the day that we put
#              easily double that 4 million number  we will  have over 20 million swabs that
#                      that were going to send out  we will  have over 15 million tubes of
#                      saying first of all is that  we will  have coronavirus in the fall i
#                      but — and eventually well —  we will  have that i think its important
#                      thing when we have that and  we will  have that so with that id
#                        what i believe they can —  we will  have and there will be enough
#                        again by the end of april  we will  have put well over 5 million
#         concerned about the most vulnerable then  we will  have to have increased testing to
#                 today it is our expectation that  we will  have tested more than 5 million
#                   may and more than 120000 total  we will  have by the end of the
#                          to have that for us and  we will  have either a response or maybe
#                       on the fact that very soon  we will  have an antibody test that americans
#                         do a thing like that but  we will  have succeeded in many ways hopefully
#                       beating it yet but i think  we will  have a very good chance to
#                           we do have — i believe  we will  have roughly four separate clinical trials
#                    when the next fall comes that  we will  have a vast array so that
#                          we get to the fall that  we will  have this under control enough that
#               close and were building it rapidly  we will  have — early next year well
#                     the way we believe they will  we will  have millions on the market by
#                with this going back to normality  we will  have in place the capability of
#                        need to have in place and  we will  have that in place is that
#              the american people and ensure that  we will  have the resources to meet this
#                      have in place and i believe  we will  have in place is a much
#                            mean we — think of it  we will  have spent 8 trillion and you
#                    back were way pulled back but  we will  have spent 8 trillion in the
#                      soon but we want 2 trillion  we will  have spent in the middle east
#                of different options that i think  we will  have soon and it will be
#                         now if they do need them  we will  have them there before they need
#                    the minimum side then i think  we will  have — hey look its still
#                optimistic person let me tell you  we will  have thousands of ventilators and what
#              dont continue to maintain that that  we will  have a resurgence right within the
#                      the day will soon come when  we will  heal our land and well be
#                         not going to be too long  we will  heal our citizens and we will
#                           say is let us know and  we will  immediately drop out of the bidding
#           capacity even further beginning in may  we will  install testing capabilities in up to
#                  and prevention of the virus and  we will  keep the american people fully informed
#                      would it be — the president  we will  let you know when its appropriate
#                   this weve always told you that  we will  look at the facts and we
#              manner that their states reopen and  we will  look to support them in that
#                          going to look at it but  we will  look at ending funding qand to
#                  every governor on the call that  we will  make all of those laboratories available
#       influence some of the recommendations that  we will  make but i can assure you
#      innovative solutions to these hard problems  we will  make progress today we were briefing
#                       we will assess it and then  we will  make adjustments from there we may
#           here and kill additional americans and  we will  marshal whatever assets are required to
#                  to make that decision and maybe  we will  maybe we wont but well have
#               of companies and the employees and  we will  meet any challenges we face by
#               be extremely clear about one point  we will  move heaven and earth to safeguard
#                    and preparing it now for what  we will  need in the future and i
#                providing tests at the level that  we will  need them for any of the
#                   we think there is a likelihood  we will  need more money and we will
#                     will get a good vaccine that  we will  never have to get back to
#                      we must not let that happen  we will  never let that happen today the
#             into effect which essentially is now  we will  never have been so focused on
#               upcoming fall and winter season so  we will  not need to resort to the
#                     — what weve just gone though  we will  not go through you could have
#                  come together its not great but  we will  not go through what we went
#           president the vice president have said  we will  not let that happen we cant
#          war on antinarcotics the president yeah  we will  not be happy if that takes
#                 venezuela but if that took place  we will  not be happy okay i will
#    their employer for expressing health concerns  we will  not tolerate retaliation osha will continue
#       no resource — financial medical scientific  we will  not spare anything well get it
#                   nobody has discussed it no but  we will  now q have any business executives
#                        of our god we will endure  we will  overcome we will prevail we have
#                  we will endure we will overcome  we will  prevail we have learned so much
#                     ive never seen it before and  we will  prevail we will win and hopefully
#                      at the money 2 trillion and  we will  probably do more i think infrastructure
#             information this week about that and  we will  provide that information in a transparent
#                     believe it is time to reopen  we will  provide them the freedom and guidance
#             everyone to have that assurance that  we will  provide you what you need over
#                       not — im not playing games  we will  pull out if we have to
#              allow instead of a blanket shutdown  we will  pursue a focus on sheltering the
#               you could speak about exactly when  we will  reach the point that some of
#                           we were able to do and  we will  rebuild that economy our economy in
#     americans can defeat any challenger together  we will  rebuild this land that we love
#                   rebuild this land that we love  we will  reclaim the magnificent destiny that we
#             energy we want to remain independent  we will  remain independent i think regardless but
#                   we will do as interagency team  we will  report back to the president and
#                will end this plague and together  we will  restore the full measure of american
#                       once we get done with that  we will  review with the president if there
#                    we will defeat this enemy and  we will  rise from this present crisis with
#              and loyalty for our fellow citizens  we will  safeguard our families care for our
#                  keep on fighting to victory and  we will  secure the glorious future that our
#           know how hes doing relatively speaking  we will  see youll probably be hearing in
#                          to see and the only way  we will  see them is if every american
#                 over the next several weeks that  we will  see potential to go under the
#                  said okay maybe with this virus  we will  see some sort of net gain
#                again i have confidence that what  we will  see is the turning around of
#                     have to defeat this enemy so  we will  see you tomorrow thank you very
#                 is a possibility that thats what  we will  see q and thats a very
#                         more money and we will —  we will  sit down and try to get
#               that together we will win together  we will  solve this problem and move on
#               of schedule and thats so important  we will  soon finalize new and very important
#                   hope and i literally pray that  we will  soon find ourselves on the downslope
#                enduring all of this together and  we will  soon prevail together were making a
#             will be reimbursed at medicare rates  we will  soon have more specifics on how
#                      i mentioned — i expect that  we will  still see the pattern that when
#                        so far out that its wrong  we will  stop that but in the case
#                          but if they cant get it  we will  take care of it yesterday the
#                        offered this to him no no  we will  take the conversation — where fortunately
#                     theyre the best in the world  we will  take every action and well spare
#                  suckers anymore so its cold out  we will  talk to you tomorrow a big
#                   about it but they werent there  we will  talk about it at the right
#                    in place that we soon believe  we will  the kind of therapeutics — i
#                     will and i feel certain that  we will  then we have to worry about
#                  will care for our neighbors and  we will  unleash the full might of the
# healthcare providers under the presidents direction  we will  use a portion of that funding
#      the information secretary mnuchin of course  we will  well give you the names as
#                to grow faster than that together  we will  win together we will solve this
#                       five weeks ago i said that  we will  win based on what the communities
#         and dedication of every american patriot  we will  win this battle we will defeat
#            this together well fight together and  we will  win together were going to win
#                    it before and we will prevail  we will  win and hopefully it will be
#             designing that like every other bill  we will  work with senators on both sides
#       economy to support hardworking americans —  we will  work with congress to get that
#               issues overnight but i promise you  we will  work with your communities to quickly
#                       in colorado that we will —  we will  work to support that effort but
#                   and fake news about this virus  we will  work with the worlds largest oil
#               mr president the president i think  we will  yeah i think were going to
#                             we — where we are so  we will  — according to the governors plans
#                 be careful in all conditions but  we will  — we will get this done
#                           lot of them so i think  we will  — we will come up with
#                     going to let that happen and  we will  — theyll shoot them out of
#                      we will need more money and  we will  — we will sit down and
#             to encourage people in colorado that  we will  — we will work to support
#                   folks thats great dr fauci and  we will  — oh how are you thank

# %% [markdown]
# ### We're working: March

# %%
mar_kwic_wereworking= make_kwic2("were working", mar_tokens, win=6)

# %%
print_kwic(sort_kwic(mar_kwic_wereworking , order=['R1']))
# Out:
#                         i want to tell you folks  were working  247 on this were going to
#                       for the people of new york  were working  along with him and then i
#              the patients can be protected again  were working  also with logistics and if you
#       likewise building hospitals in los angeles  were working  also — the state of washington
#                          wont do well at all but  were working  also with the hotel industry but
#           medical supplies from around the world  were working  as we speak on an airlift
#                        i want to assure you that  were working  as quickly as we can i
#              working very closely with italy and  were working  closely with spain too which is
#             under the authority of each governor  were working  constantly with the department of defense
#              but to your very important question  were working  day by day with the largest
#                       and in fact were working —  were working  diligently right now with that supply
#         13 different airports around the country  were working  diligently in that regard to put
#                thank you mr president at labcorp  were working  every second of every day to
#                      a worst case and thats what  were working  for yes q mr president im
#        california were getting along really well  were working  hard for him as you know
#               lives at the department of justice  were working  hard to protect the health and
#                  in availability of ppes now and  were working  hard to correct that but currently
#           pandemic office and the officials that  were working  in that office left this administration
#                    date of monday march 16th and  were working  literally around the clock and i
#             refer to secretary kadlec to respond  were working  literally hour by hour with the
#                  our mitigation methods — we all  were working  off of that same model and
#                       but what were doing is now  were working  on the virus were working on
#                    now were working on the virus  were working  on that hidden enemy and i
#                 people that are already sick and  were working  on that at a level that
#              were getting some good response and  were working  on therapeutics and cures and we
#                 make that decision so thats what  were working  on right now is getting that
#                       to do their job safely and  were working  on that i will tell you
#                    that will utilize less ppe so  were working  on making sure supply gets where
#           protected and a family needs protected  were working  on job retention loans for small
#              access as we talked about yesterday  were working  on the ability for people to
#                        igg and igm so thats what  were working  on right now q so realistically
#                        gavin newsom and we are —  were working  on getting that done very quickly
#            being very protective of our veterans  were working  on certain hospitals where we may
#                      solve the problem of — that  were working  on — the medical problem so
#              underway for many new therapies and  were working  on scaling these to allow many
#                      of young people in peru and  were working  on taking care of that with
#                   alabama and theyre in peru and  were working  on that right now trying to
#                    these are the kinds of things  were working  on right now and hes getting
#                us know the results the president  were working  on that were working out a
#            azar masks overall the vice president  were working  on — ill be traveling to
#               the president were working on that  were working  out a schedule q my second
#                    quickly to enact for higher —  were working  quickly to enact for traditional higher
#                    speak to that along with tony  were working  quickly to pass additional legislation that
#                      for people to be tested and  were working  right now with state and local
#                yesterday at the place where they  were working  so that we wouldnt disturb them
#              to him in deploying those medicines  were working  specifically with one state to do
#                          so one of the ways that  were working  through that at fema now is
#               couple of their hospitals have and  were working  through the strategic — strategic national
#              resource to the american people and  were working  to make testing happen faster we
#               a doctors indication be tested now  were working  to fill that need and were
#                    that risk is of course higher  were working  to keep that risk low we
#           are very committed were very committed  were working  together and were getting things out
#                      perdue to share more on how  were working  together to help support student nutrition
#                        ideas a lot of good ideas  were working  together the leaders gathered virtually around
#                 comments the other day about how  were working  together we worked on the ship
#                  those two great friends of mine  were working  urgently with congress on legislation to
#          speaking of pharmaceuticals as you know  were working  vaccines were getting some good response
#                     and then it explodes and now  were working  very carefully and very powerfully with
#                  whatever you want the virus but  were working  very hard thats all i know
#                       we are helping italy a lot  were working  very closely with italy and were
#                        very high so is spain but  were working  very closely with them yes we
#                       lot of time in south korea  were working  very hard on that • prime
#                       a large group of people so  were working  very hard to get that antibody
#           were building him four medical centers  were working  very very hard for the people
#                     as soon as possible they see  were working  very hard on that thats a
#                       we begin i want to mention  were working  very hard — long — on
#               available by the tens of thousands  were working  very diligently with an incredible response
#              one young gentleman austin tice and  were working  very hard with syria to get
#              you have a problem with ventilators  were working  very hard trying to find —
#                           what i can tell you is  were working  very closely with the company on
#                        until the end of april so  were working  very closely with dr ben carson
#                           just the way it is but  were working  very closely together were also getting
#                  states q right the president so  were working  very closely with canada and —
#                    and that was with symptoms so  were working  very hard integrating everything they have
#                 had a very good conversation and  were working  very strongly with many states including
#                think you have to remember though  were working  very closely with states and you
#                 established i will tell you that  were working  very closely with california washington new
#                           day and also dr birx —  were working  very diligently to establish a single
#         comorbidities or other conditions and so  were working  very hard with the people on
# americans through particular airports the screening  were working  very closely with the airlines on
#          and solve some realworld problems today  were working  with the air force to try
#                       really hit hard and were —  were working  with everybody i spoke with angela
#                  where we dont have the latitude  were working  with congress on solutions one area
#                      six months to produce it so  were working  with a variety of companies to
#               — probably recovery phase and then  were working  with companies to work on getting
#              are continuing to evaluate the data  were working  with the task force and making
#                   also — the state of washington  were working  with the governor of the state
#                   think that — the president jon  were working  with all of them q —
#             even earlier the president sure sure  were working  with all of them we can
#             a line of effort called reallocation  were working  with our industry partners to illuminate
#    process of reviewing recommendations from cdc  were working  with the department of homeland security
#                  just mentioned — in many states  were working  with governor ron desantis in florida
#            with governor ron desantis in florida  were working  with governor mcmaster — right —
#                   by comparison but a little bit  were working  with many many governors and many
#                      theyve done a great job but  were working  with many states and thats primarily
#                  and to many other countries and  were working  with — as the doctor can
#                          — as the doctor can say  were working  with many countries with respect to
#               that device can be changed readily  were working  with the fda to approve that
#                 secretary mnuchin is on the hill  were working  with democrats and republicans and theres
#  distribution of essential supplies if necessary  were working  with congress to provide major additional
#          officials on the subject of ventilators  were working  with healthcare providers around america and
#               with governors this afternoon — is  were working  with governors to make sure that
#                            do our best on it but  were working  with democrats and republicans on that
#                   we are working with the states  were working  with the governors were working with
#           states were working with the governors  were working  with everybody the relationships are great
#                      you that what were doing is  were working  with local governments — with states
#               that to proceed moving forward and  were working  with a number of different other
#         further steps to expand testing capacity  were working  with several groups to determine if
#         americans the president to be determined  were working  with the senate right now were
#                working with the senate right now  were working  with everybody on capitol hill theres
#              theyve done an incredible job again  were working  with the states and relying on
#                 what weve really designed in how  were working  with the states we have contacted
#          and individual jurisdictions as well as  were working  with google and other tech companies
#                       me say that were working —  were working  with google but were working with
#                   — were working with google but  were working  with many other tech companies and
#                     certain areas yes we are and  were working  with the states and we are
#                         of tests that we can run  were working  with academic medical centers with our
#                        not doing well at all but  were working  with a lot of groups of
#              originally — origins from italy and  were working  with them theyre in a very
#         coronavirus tests all across america and  were working  with state local officials to ensure
#                    — which obviously will be hit  were working  with them very very strongly we
#                 out sooner rather than later but  were working  with the industries and in particular
#                  that this is for every american  were working  with communities like the seattle area
#              is its around infection control and  were working  with the entire healthcare industry today
#                      be taken back to canada and  were working  with the united kingdom to return
#                  is a whole government of effort  were working  with department of defense with the
#          identified before — travis lackland and  were working  with the department of defense to
#           tested as positive for the coronavirus  were working  with the airlines to get all
#                             so what — but were —  were working  with members of congress and well
#                      viability of it and in fact  were working  — were working diligently right now
#                             me — let me say that  were working  — were working with google but
#                     to the bottom of things also  were working  — our drug companies our pharmaceutical
#                       are known as n95 masks and  were working  — senator deb fischer and others

# %% [markdown]
# ### We're working: April

# %%
apr_kwic_wereworking= make_kwic2("were working", apr_tokens, win=6)

# %%
print_kwic(sort_kwic(apr_kwic_wereworking , order=['R1']))
# Out:
#    15 days the presidents coronavirus guidelines  were working  and thats precisely why president trump
#                     stone unturned as i said and  were working  around the clock to develop these
#                             a day now but were —  were working  around the clock to scale up
#           today as an antimalaria medication but  were working  around the country and internationally to
#                 america and to stay open america  were working  around the clock to continually expand
# undertested underserved and minority communities and  were working  closely with partners and states to
#              were working with the governors and  were working  closely with the governors the relationship
#                         to be a real focal point  were working  closely with governor gretchen whitmer as
#                     birx yeah thank you so while  were working  diligently in the midst of the
#           million people were killed in addition  were working  directly with hospitals and existing suppliers
#                  that were really focused on and  were working  feverishly to make sure that we
#                direct hires but local people who  were working  for the state department and embassies
#                   that are — were developing and  were working  ill be happy to answer questions
# disproportionately affecting our minority communities so  were working  in partnership with organizations like the
#                we think theyre going to delaware  were working  it out but 500 excess ventilators
#                     of 180 million n95 masks and  were working  now with 3m to see whether
#                    this is a universal issue but  were working  on it as a collective to
#                          flu were going to — and  were working  on an algorithm that you test
#                           this is a big deal and  were working  on it and were working with
#                          lot i learned a lot and  were working  on some things that are very
#                       so well so these are tests  were working  on today that would be like
#                       clinic and so this is what  were working  on for the future next slide
#                  those are the three states that  were working  on building capacity in so this
#                  are just some insights and what  were working  on were continuing obviously to track
#                        keep those jobs so were —  were working  on it i think eventually its
#              home we still have several thousand  were working  on it we chip away at
#             be doing that analysis the president  were working  on that very hard this is
#              to assure the american people while  were working  on these outbreaks were also working
#               assure the american people that as  were working  on the crisis of today were
#                    provided for at the same time  were working  on tests and assays that will
# to execute the presidents counternarcotics strategy  were working  on a number of important national
#                  i think about and its something  were working  on please q can i ask
#                     whats really — so thats what  were working  on q so why arent they
#                    die as possible and thats all  were working  on q i know you dont
#                 were getting them what they need  were working  out cost arrangements with them and
#                   cash payment to the people and  were working  out the mechanics of that with
#         that they provide to uninsured americans  were working  out the details of that the
#                       one i love them number two  were working  really hard it wasnt their fault
#                          i can tell you that and  were working  really very hard with new york
#               there that have not been validated  were working  right now very closely with a
#                            i say is we love them  were working  so hard and theyre going to
#          still have several thousand people that  were working  they identify themselves every day new
#                     in the food supply chain but  were working  through that and all this —
#                    un directly but also that you  were working  to find out if those reports
#            about the supplies and resources that  were working  to provide for all of them
#                 151 nations are going through it  were working  to ensure that the supplies are
#                 100 billion will go to providers  were working  to ensure that this funding is
#                   doing down to the county level  were working  to get it potentially down to
# the communitybased and drivethrough testing that  were working  to transition over completely all of
#     to write a prescription for hydrochloroquine  were working  today to make that available across
#     medicines agency theyre all working together  were working  together with a lot of other
#                       on that but the vaccines —  were working  together with other countries were also
#                     a great call the other night  were working  together on a lot of different
#                     they needed as i said people  were working  until 4 oclock i believe we
#                      really good job in new york  were working  very closely with each of the
#                        coke and pepsi so i think  were working  very deliberately to really be able
#        to be doing it beautifully systematically  were working  very well with the governors i
#                       guys but for the most part  were working  very well with the governors we
#               from the standpoint of our country  were working  very well with them — south
#            medical professionals and — and again  were working  very closely with the president and
#                      how to do and its something  were working  very closely with cdc and others
#         prosperous and continue to be prosperous  were working  very hard to make sure our
#                          to do i think thats why  were working  very hard for two pieces and
#            airlines and the airline business and  were working  very closely with a lot of
#         its transitioned to disposable gowns and  were working  very rapidly in the next 24
#                couple of answers on that because  were working  very hard on the african american
#                  as quickly as possible so again  were working  very well with the governors now
#              the governor has been very thankful  were working  very hard with new jersey including
#                 good i spoke with governor cuomo  were working  very hard to get additional things
#                    going to be working very hard  were working  very hard we are really coming
#              11 million tests around the country  were working  very closely with governors around america
# hospitals particularly with regard to ventilators  were working  very closely hhs is fully integrated
#                         i have to be honest they  were working  very hard were making thousands and
#                to numerous senators about it and  were working  with senators that are on the
#                   and maybe this but in parallel  were working  with states and local governments to
#                       get it that are very small  were working  with the banks were extremely pleased
#                 these antibody tests one is that  were working  with cdc and nci to actually
#                        were — what were doing is  were working  with folks around the country but
#           of machines match their population and  were working  with the walter reed group and
#                       and were working on it and  were working  with the companies and i think
#            turned down its pretty amazing nobody  were working  with the worldclass team at oak
#                  job hes doing is incredible and  were working  with scott his predecessor whos terrific
#         with scott his predecessor whos terrific  were working  with a lot of people but
#                   to be watching it very closely  were working  with them on testing were working
#                were working with them on testing  were working  with them on whatever they need
#                        month and so this is what  were working  with each of those states on
#                         be over a period of time  were working  with some really great people —
#               fda we have incredible people that  were working  with and were going to bring
#                    be open to the vice president  were working  with all of our inaudible thank
#             — along with other nations hopefully  were working  with other nations — well be
#                          we dont want to do that  were working  with the governors and were working
#                  i think theres always things so  were working  with larry kudlow i mean we
#                      and we encourage — you know  were working  with the states to try to
#              distributed those to the states but  were working  with the states to not only
#                       going to take care of them  were working  with them right now we have
#                         had in the states and so  were working  with governors on that and well
#         thousands of machines across the country  were working  with hospitals and labs around the
#      transportation companies hotels you name it  were working  with them to make sure the
#                  members of congress that so far  were working  with more than 3600 lenders across
#                         a clue whats going on so  were working  with other nations trying to get
#              has had really incredible results —  were working  with the fda and everybody else
#          the states have that responsibility but  were working  with the states and were getting
#                       we have a great system now  were working  with the states in almost all
#               from certain areas so knowing that  were working  with the governors q mr president
#            demand of everything including oil so  were working  with our great energy companies these
#                      we took the sick people and  were working  with them we have doctors we
#             youre fighting this battle from home  were working  with the best scientists doctors and
#                     short period of time — again  were working  with the states on enhanced unemployment
#             people who are underbanked and again  were working  with all the digital companies prepaid
#        the digital companies prepaid debit cards  were working  with all of them to make
#                    forefront of all of our minds  were working  — working to make it possible

# %% [markdown]
# ### Have Enough: April

# %%
apr_kwic_haveenough = make_kwic2("have enough", apr_tokens, win=6)

# %%
print_kwic(sort_kwic(apr_kwic_haveenough, order=['R1']))
# Out:
#            governors are still wondering do they  have enough  bed space and whats important here
#                       does not mean that we dont  have enough  food in this country to feed
#                            20 people a day now i  have enough  for thenext three days if that
#                have enough ventilators yes do we  have enough  hospital beds yes weve built 20000
#                weve built 20000 hospital beds we  have enough  hospital beds go ahead jim lets
#                  them because they say they dont  have enough  illinois said they didnt have enough
#                    some of these questions do we  have enough  masks no do we have enough
#                    president but you asked do we  have enough  masks yes q we hear from
#                          say that you said do we  have enough  masks yes q does the country
#                   dont have enough tests we dont  have enough  masks the president the governor —
#                       pandemic why is it we dont  have enough  masks why is it we dont
#                          masks why is it we dont  have enough  medical equipment in this country the
#                there was full takeout we wouldnt  have enough  money thats why weve worked with
#                  is the timeline for when theyll  have enough  of them because they say they
#                       q — ppe obviously you dont  have enough  of — the president no no
#                    of certain things and we dont  have enough  of others i just had a
#                       have enough tests no do we  have enough  ppe no do we have enough
#                          dont need to do it they  have enough  problems iran has enough problems without
#                    states dont want to take they  have enough  problems right now they dont want
#             have enough illinois said they didnt  have enough  so whats the timeline that youre
#               our capacity and confident that we  have enough  testing to begin reopening and the
#                    that by our best estimates we  have enough  testing capacity today for every state
#                     that may occur once again we  have enough  testing capacity for every state in
#                   screened for covid19 and we do  have enough  testing capacity to do both that
#                  physical separation q but do we  have enough  testing — the vice president how
#                           go right ahead q do we  have enough  testing capacity in the country right
#                       me mr vice president do we  have enough  testing right now the vice president
#                     quick followup on that if we  have enough  tests right now for everyone to
#          health experts assess that states today  have enough  tests to implement the criteria of
#                     we have and will continue to  have enough  tests to safely go into phase
#                       have enough masks no do we  have enough  tests no do we have enough
#                       does — the president do we  have enough  tests yes plus were developing new
#                             q — say that we dont  have enough  tests we dont have enough masks
#                     but he was saying they didnt  have enough  that they needed to start to
#                             job we still — if we  have enough  time to go build we want
#                           we have enough — do we  have enough  ventilators yes do we have enough
#               said they feel that they currently  have enough  ventilators — i think a lot
#                       lot of people are going to  have enough  ventilators — and masks and appreciate
#                         have enough ppe no do we  have enough  — the president why would you
#                        not — the president do we  have enough  — do we have enough ventilators

# %% [markdown]
# ### In Fact: April

# %%
apr_kwic_infact = make_kwic2("in fact", apr_tokens, win=6)

# %%
print_kwic(sort_kwic(apr_kwic_infact, order=['R1']))
# Out:
#                 to the indian health service and  in fact  1800 members of the public health
#              people dont need a pointofcare test  in fact  a pointofcare test does not —
#           new cases and the hospitalizations are  in fact  a reflection of the results of
#                       the us developed a plan if  in fact  a second wave of the virus
#               back q inaudible mr president that  in fact  are you suggesting — the president
#            the nation literally by the thousands  in fact  as we stand here today 576
#             soon would that happen the president  in fact  certain hospitals — yeah certain hosp
#               beginning we appreciate it so much  in fact  dr fauci is here maybe i
#                       sense of deaths a bad week  in fact  every day there seems to be
#       country have no reported coronavirus cases  in fact  half of the states in america
#                  tremendous — hes a tremendous —  in fact  he recently got the presidential medal
#                            im going to be spea —  in fact  he has a call in to
#                   that jon — friday nights right  in fact  his was later friday night than
#         opportunity for insurance companies — if  in fact  hospitals are compensated for uncompensated care
#                with the website just not working  in fact  i heard from the american bankers
#                      country in the world by far  in fact  i think i read where if
#        we have tremendous numbers of ventilators  in fact  i — i hear — i
#                      work that out at some point  in fact  i guess theyre going to be
#                  control that flow as an example  in fact  i just saw a little while
#               is good were reporting every death  in fact  i see this morning where new
#              biden i was criticized by everybody  in fact  i was called xenophobic i was
#                have great respect for this group  in fact  i told tony fauci — i
#                 this right somebody was saying —  in fact  i was speaking with governor cuomo
#                        i will see whether or not  in fact  i called up just a little
#                                — if it were me —  in fact  i might do it anyway i
#                            you sir i dont want —  in fact  i want to praise the states
#             back itll keep our restaurants going  in fact  i think the restaurant business will
#                   coming back would be a vaccine  in fact  i was on the weekly conference
#                         i said im not firing him  in fact  if you ask your friends in
#             accurate in the reporting of numbers  in fact  ill go a step further as
#             house with my children the president  in fact  im thinking about moving outside to
#                       were going to find out and  in fact  im scheduled to speak to the
#                 treatment this is an old concept  in fact  immunology was born decades and decades
#                       this barrier in case i was  in fact  infected if i didnt know is
#                           will you — or will you  in fact  invoke the dpa to force that
#              all give back their pulitzer prizes  in fact  it turned out that the crime
#                         this as a bad thing when  in fact  it is a great thing because
#           a great focus on pandemic preparedness  in fact  it was just in november i
#                        be the tip of the iceberg  in fact  itd be the iceberg underneath the
#                and much of its being distributed  in fact  itll start going down what we
#                           to be a problem at all  in fact  its going to be one of
#                          hard for me to say that  in fact  its impossible for me to say
#                 its related to a covid infection  in fact  its the opposite having an underlying
#                    of covid19 and its possibly —  in fact  likely — that the burden of
#                   approval of the 15 minute test  in fact  mayor duggan told me that he
#            all over ventilators by the thousands  in fact  mike got back from wisconsin the
#                    we can to accomplish that and  in fact  mitigation works you saw the charts
#       an overflow healthcare facility in chicago  in fact  mr president mayor lightfoot told me
#                deaths compared to the day before  in fact  new york today had again another
#                    second wave of the virus does  in fact  occur here in the country dr
#              everybody is doing exactly the same  in fact  our record is better than states
#                 is strong resilient and safe and  in fact  our food supply chain has shown
#       concerns about exposure to the coronavirus  in fact  over the last several days theres
#                             a list — what we did  in fact  part of it was up there
#                used for the covid19 outbreak are  in fact  regulated by fda the staff have
#                     been very good on the border  in fact  right now the border is stonecold
#               have seen this pandemic coming but  in fact  secretary azar at a biodefense summit
#          than doubled thousands of ventilators —  in fact  so many ventilators that the governor
#               protective equipment as you know —  in fact  some of the people here are
#                   itll be scaled up very quickly  in fact  some of the companies — johnson
#                   and theyre not accurate at all  in fact  some of the tests you dont
#                  themselves by at least six feet  in fact  some of the restaurants had little
#              say they have it fixed undisputably  in fact  somebody said — they gave me
#        drivethrough sites all across the country  in fact  states have been so successful with
#                if the department of justice will  in fact  support — q jenn pellegrino with
#                          — a test that tells you  in fact  that youve been infected thats really
#                    would be concern by some that  in fact  that might have some negative consequences
#                    lot of them being shipped and  in fact  thats why general motors called up
#           from those two facilities to hospitals  in fact  the president and i were just
#                      end up being a big strength  in fact  the other countries — other countries
#                            is that part of the —  in fact  the major reason to wear a
#                       you dont have to wear them  in fact  the director is here if you
#                        in a short period of time  in fact  the graph could have been even
#                   the spread is working and that  in fact  the american people are putting these
#                        we get into the summer if  in fact  there are cases out there when
#               6 percent higher than in singapore  in fact  theres a typo its 67 percent
#                       they didnt want to do this  in fact  they specifically didnt want to do
#                not even close to accurate counts  in fact  theyre insulting to look at them
#                       even have room to store it  in fact  theyre using ships to store oil
#                       ago hes got plenty of beds  in fact  theyre having a hard time filling
#                   — are having a positive effect  in fact  today california and washington state where
#                    either have them or they dont  in fact  we went to one meeting —
#                       that weve been asked a lot  in fact  we had a very productive teleconference
#              of the hypothetical question was if  in fact  we had mitigated earlier could lives
#                     job we built over 20000 beds  in fact  we built thousands more than weve
#              the material now they have machines  in fact  we — were going to go
#                     what the president a lot and  in fact  well give you a list —
# hispanic communities the numbers are disproportionate  in fact  were doing big studies on it
#      hearing people are needing ventilators much  in fact  were going to start helping other
#                that new cases were down slightly  in fact  were seeing a trend of some
#                and are working their way through  in fact  weve had three fatalities of local
#                         a great test as that and  in fact  what ill do — i think
#             that nobody thought was possible and  in fact  when they did the models as
#                    to modeling a very low number  in fact  when i first saw the number
#                theyre getting hit very very hard  in fact  while we have tony here id
#                       i would be in such trouble  in fact  youll put me in trouble just
#                hundreds of thousands of jobs and  in fact  your paper wrote an incredible editorial
#                        no country is close to us  in fact  — and i appreciate it very
#                stabilize oil markets and we have  in fact  — and i think youve seen
#  same thing its mitigation mitigation mitigation  in fact  — laughs — looks for chart

# %% [markdown]
# ### Oil: April

# %%
apr_kwic_oil = make_kwic("oil", apr_tokens, win=6)

# %%
print_kwic(sort_kwic(apr_kwic_oil , order= ['R6']))
# Out:
#                  please q thank you mr president  oil  is trading today at about 23
#          our reserves with this very inexpensive  oil  nobody thought theyd ever see a
#          to let american producers store surplus  oil  that can be sold at a
#                  water is far more valuable than  oil  theres so much oil its a
#              for national security and also will  oil  companies fit into that at all
#                           now there was a lot of  oil  but it was very controllable all
#                        in order to agree to that  oil  deal the president yeah q and
#                          because it has a lot of  oil  underneath — oil and gas and
#               ever the airlines were doing great  oil  was doing great — oil and
#                            so there was a lot of  oil  production to start off with and
#                    the market so theres too much  oil  theres a glut and these are
#                     a great oil industry and the  oil  industry is being ravaged and as
#                 room we certainly have plenty of  oil  so ill take a look at
#                      very very happy steve q did  oil  executives ask you for a bailout
#                  oil prices the president yeah q  oil  prices are at 23 a barrel
#              countries around the world will cut  oil  production by approximately 20 million barrels
#               are storing millions of barrels of  oil  that nobody thought would even be
#                 a marketdriven economy and — and  oil  is very market driven theyve been
#                          have — theres a glut of  oil  like nobody has ever seen before
#              opened the press conference with on  oil  us crude futures today went below
#                 something where we only used our  oil  but i think the longterm benefit
#                reserve right now its like having  oil  reserves except more valuable frankly but
#                           is a great time to buy  oil  and wed like to have congress
#           very market driven theyve been cutting  oil  all over the place were cutting
#                          we worked out a deal on  oil  that was a very important deal
#                 united states would not bail out  oil  drillers here the president we didnt
#                    agree to cut us production of  oil  the president no no we didnt
#                   our industry does well and the  oil  industry does better than its doing
# worlds largest oilproducing countries to stabilize  oil  markets and we have in fact
#            least theres just an overabundance of  oil  right now — oil and gas
#                will work with the worlds largest  oil  producers to address volatility in global
#      just stopped demand of everything including  oil  so were working with our great
#               president its like from 1950 these  oil  prices and thats when they had
#                     obviously in the case of the  oil  industry theyve been hit especially hard
#                           quickly q why — on the  oil  why do you think you havent
#                     coming together on a deal on  oil  but in the last 24 hours
#                 you never thought youd be seeing  oil  at 20 a barrel but how
#                        bet you know the price of  oil  right now dont you q i
#                         do you know the price of  oil  laughter the president i do i
#                          i have to do tariffs on  oil  coming from outside or if i
#                           can i just check in on  oil  again today i was wondering if
#                      great oil was doing great —  oil  and gas and the energy industry
#                 states the president well if the  oil  price stays the way it is
#                        well look we have a great  oil  industry and the oil industry is
#                             had a big talk as to  oil  production and opec and making it
#                 overabundance of oil right now —  oil  and gas tremendous overabundance and it
#                  based on the recordlow price of  oil  that youve been seeing — its
#                   periods of time theres so much  oil  in some cases its — its
#                      building what we do for the  oil  and engineering firms so you know
#                        a lot of oil underneath —  oil  and gas and as you know
#                   much discussed the oil and the  oil  prices i mean if you look
#                      of energy to start off with  oil  in particular we had a lot
#           second question on economics just with  oil  — oil prices are very low
#                  both we very much discussed the  oil  and the oil prices i mean
#                  were the number one producer of  oil  in the world and a month
#                          just — i heard from the  oil  executives these are people — most
#              economic wellbeing is from oil well  oil  is at a record low nobody
#                 the production and the amount of  oil  being produced and frankly theres not
#                   — massive areas for storage of  oil  — because oil today is not
#               our biggest industries — thats the  oil  industry its really — its not
#                     dont know if you know theres  oil  all over the oceans right now
#                          of ground with a lot of  oil  in it i think were number
#                      dont want to lose our great  oil  companies you know were the number
#                  opening up areas for storage of  oil  — massive areas for storage of
#                            i have one for you on  oil  — the president a bunch of
#                       done to work on industry —  oil  industry jobs — to save oil
#                           get rid of the glut of  oil  theres a tremendous glut of oil
#              and some other countries to discuss  oil  prices the president yeah q oil
#                   be saying we dont want foreign  oil  we dont want any foreign oil
#                       you saw the front month of  oil  futures trade negative q hi on
#                 sitting out there loaded up with  oil  so we want to save our
#                     oil we dont want any foreign  oil  were just going to use our
#        producers to address volatility in global  oil  markets we will always protect our
#                  imports — tariffs on imports of  oil  to the united states the president
#         you considering tariffs on saudi arabian  oil  and then also — the president
#                     on economics just with oil —  oil  prices are very low the president
#                            it up load it up with  oil  that frankly is — had pricing
#                         to keep it at that level  oil  is important for mexico the problem
#              mentioned the 75 million barrels of  oil  that — the president yes q
#               im going back into negotiations on  oil  and on airlines yeah please q
#              of their economic wellbeing is from  oil  well oil is at a record
#                other things were doing is having  oil  shipped to our strategic oil reserves
#                  is right now more valuable than  oil  who would have ever thought right
#                       i have a quick followup on  oil  please in your conversations with russia
#                   it was probably about that the  oil  prices because as you know russia
#                       sir just a followup on the  oil  question the president of mexico said
#                im going to meet with independent  oil  producers also on friday or saturday
#                       were just going to use our  oil  and that would help to save
#               market and now theyre flooded with  oil  look i — i just say
#              theyre — thats where theyre storing  oil  and theyre sent out to sea
#                nobody has ever heard of negative  oil  before but its for a short
#                        having it they — you know  oil  and gas are their major sources
#                     of a financial thing than an  oil  situation but — because you take
#                  independent now we have our own  oil  and if i did the tariffs
#               is now independent we produce more  oil  than — oil and gas than
#                       we produce more oil than —  oil  and gas than anybody else than
#                    have a situation now with the  oil  business — partially because of the
#                    about what you spoke about on  oil  with president putin this morning the
#                 was wondering if — the president  oil  q yeah if theres — the
#            time theres a tremendous abundance of  oil  primarily because of the virus the
#                   the us willing to cut domestic  oil  production what came out of the
#               that youve spoken about liking low  oil  prices but then theres also the
#                    not here i mean worldwide the  oil  industry has been ravaged so there
#             that theres massive excess amount of  oil  and gas massive like probably theres
#                      was primarily a call on the  oil  as you can imagine and they
#                      oil industry jobs — to save  oil  industry jobs after the deal this
#                 fact theyre using ships to store  oil  theres never been anything like this
#                  oil theres a tremendous glut of  oil  and we dont want anything to
#                  water is more valuable than the  oil  you never thought youre going to
#                        im going to meet with the  oil  companies on friday im going to
#                      who are supported by the us  oil  and gas industry its a very
#                      called on you to stop saudi  oil  shipments that are on the way
#                 valuable than oil theres so much  oil  its a tribute in a way
#              having oil shipped to our strategic  oil  reserves okay and you know were
#                     for storage of oil — because  oil  today is not selling and what
#               an expensive process in itself but  oil  is getting to a point where
#                     the extent that they are the  oil  has dropped to a point where
#                     the toolbox as it relates to  oil  you hashed out the deal with
#                      president yeah q — with the  oil  output situation the president yeah yeah
#                         you later q going to the  oil  meeting previously — the president yeah
#                     people has been the state of  oil  prices right now the president yeah
#                    president i want to follow on  oil  when you were talking earlier you
#                         they pay you to take the  oil  but thats a shortterm squeeze you
#                     with russia we worked on the  oil  deal together i was with —
#                           them am i using it for  oil  its something we can no —
#         is being hurt unbelievably badly because  oil  and gas is a primary —

# %% [markdown]
# Trump is bailing out oil industry
